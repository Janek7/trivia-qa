# %% [markdown]
# # BM25
#
# For reference see: [Improvements to BM25 and Language Models Examined](http://www.cs.otago.ac.nz/homepages/andrew/papers/2014-2.pdf)

# %%
import pandas as pd
import numpy as np
# !pip install pickle5
import pickle5 as pickle
import os
from collections import Counter
import re


from google.colab import drive
# Out:
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.11)

# %%
 # !python --version
# Out:
# Python 3.7.10

# %% [markdown]
# ## Files and Folders

# %%
drive.mount('/content/drive', force_remount=True)  # use force_remount=True param after upload of new data

# file and folder names
ir_project_drive_folder = "IR Projekt"  # TODO: geht das für alle?
full_ir_project_drive_folder = "/content/drive/My Drive/{}/data/wikipedia".format(ir_project_drive_folder)
#full_ir_project_drive_folder = '../data/wikipedia'

# preprocessed files
preprocessed_folder = full_ir_project_drive_folder + '/no-pron/preprocessed'

preprocessed_wikipedia_evidence_file = preprocessed_folder + '/preprocessed_wikipedia_evidence_dict.pkl'
preprocessed_qa_wikipedia_verified_dev_filename = preprocessed_folder + '/qa/verified-wikipedia-dev.pkl'
preprocessed_qa_wikipedia_dev_filename = preprocessed_folder + '/qa/wikipedia-dev.pkl'
preprocessed_qa_wikipedia_test_without_answers_filename = preprocessed_folder + '/qa/wikipedia-test-without-answers.pkl'
preprocessed_qa_wikipedia_train_filename = preprocessed_folder + '/qa/wikipedia-train.pkl'

## retrieval
bm25_results_folder = full_ir_project_drive_folder + '/no-pron/bm25'

bm25_retrieval_wiki_dev_docs_scores = bm25_results_folder + "/retrieval_wiki_dev_docs_scores.pkl"
bm25_retrieval_wiki_dev_verified_docs_scores = bm25_results_folder + "/retrieval_wiki_dev_verified_docs_scores.pkl"
bm25_retrieval_wiki_test_docs_scores = bm25_results_folder + "/retrieval_wiki_test_docs_scores.pkl"
bm25_retrieval_wiki_train_docs_scores = bm25_results_folder + "/retrieval_wiki_train_docs_scores.pkl"
# Out:
# Mounted at /content/drive

# %%
def save_as_pickle(obj, filename):
    """
    save an object in a pickle file dump
    :param obj: object to dump
    :param filename: target file
    :return:
    """
    directory = os.path.dirname(filename)
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    with open(filename, 'wb') as file:
        pickle.dump(obj, file, protocol=pickle.HIGHEST_PROTOCOL)


def load_pickle(filename):
    """
    load an object from a given pickle file
    :param filename: source file
    :return: loaded object
    """
    with open(filename, 'rb') as file:
        return pickle.load(file)

# %% [markdown]
# ## Load Data

# %%
# Evidence data: Wiki (Preprocessed)

documents_dict_wiki = load_pickle(preprocessed_wikipedia_evidence_file)
print(len(documents_dict_wiki))
# Out:
# 73930

# %%
# Query Data: Wiki Dev Set (Preprocessed)
qa_wiki_dev_dict = load_pickle(preprocessed_qa_wikipedia_dev_filename)

# Query Data: Wiki Dev Set - Verified (Preprocessed)
qa_wiki_dev_verified_dict = load_pickle(preprocessed_qa_wikipedia_verified_dev_filename)

# Query Data: Wiki Train Set(Preprocessed)
qa_wiki_train_dict = load_pickle(preprocessed_qa_wikipedia_train_filename)

# Query Data: Wiki Test Set(Preprocessed)
qa_wiki_test_dict = load_pickle(preprocessed_qa_wikipedia_test_without_answers_filename)

# %%
qa_wiki_dev_dict
# Out:
# [{'Answer': {'Aliases': ['Sunset Blvd',
#     'West Sunset Boulevard',
#     'Sunset Boulevard',
#     'Sunset Bulevard',
#     'Sunset Blvd.'],
#    'MatchedWikiEntityName': 'Sunset Boulevard',
#    'NormalizedAliases': ['sunset boulevard',
#     'sunset bulevard',
#     'west sunset boulevard',
#     'sunset blvd'],
#    'NormalizedMatchedWikiEntityName': 'sunset boulevard',
#    'NormalizedValue': 'sunset boulevard',
#    'Type': 'WikipediaEntity',
#    'Value': 'Sunset Boulevard'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Andrew_Lloyd_Webber.txt',
#     'Title': 'Andrew Lloyd Webber'}],
#   'Question': 'Which Lloyd Webber musical premiered in the US on 10th December 1993?',
#   'QuestionId': 'tc_33',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'lloyd webber music premier 10th decemb 1993'},
#  {'Answer': {'Aliases': ['Sir Henry Campbell-Bannerman',
#     'Campbell-Bannerman',
#     'Campbell Bannerman',
#     'Sir Henry Campbell Bannerman',
#     'Henry Campbell Bannerman',
#     'Henry Campbell-Bannerman'],
#    'MatchedWikiEntityName': 'Henry Campbell-Bannerman',
#    'NormalizedAliases': ['henry campbell bannerman',
#     'sir henry campbell bannerman',
#     'campbell bannerman'],
#    'NormalizedMatchedWikiEntityName': 'henry campbell bannerman',
#    'NormalizedValue': 'campbell bannerman',
#    'Type': 'WikipediaEntity',
#    'Value': 'Campbell-Bannerman'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Prime_Minister_of_the_United_Kingdom.txt',
#     'Title': 'Prime Minister of the United Kingdom'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Arthur_Balfour.txt',
#     'Title': 'Arthur Balfour'}],
#   'Question': 'Who was the next British Prime Minister after Arthur Balfour?',
#   'QuestionId': 'tc_40',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'next british prime minist arthur balfour'},
#  {'Answer': {'Aliases': ['Internal exile',
#     'Exiles',
#     'Transported for life',
#     'Exile (politics and government)',
#     'Voluntary exile',
#     'Sent into exile',
#     'Exile and Banishment',
#     'Self-exile',
#     'Forced exile',
#     'Exile',
#     'Exile in Greek tragedy',
#     'Banish',
#     'Banishment'],
#    'MatchedWikiEntityName': 'Exile',
#    'NormalizedAliases': ['exiles',
#     'voluntary exile',
#     'forced exile',
#     'banish',
#     'self exile',
#     'exile politics and government',
#     'exile in greek tragedy',
#     'sent into exile',
#     'banishment',
#     'transported for life',
#     'exile',
#     'internal exile',
#     'exile and banishment'],
#    'NormalizedMatchedWikiEntityName': 'exile',
#    'NormalizedValue': 'exile',
#    'Type': 'WikipediaEntity',
#    'Value': 'Exile'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Kiss_You_All_Over.txt',
#     'Title': 'Kiss You All Over'}],
#   'Question': 'Who had a 70s No 1 hit with Kiss You All Over?',
#   'QuestionId': 'tc_49',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': '70 1 hit kiss'},
#  {'Answer': {'Aliases': ['Cancer pathology',
#     'Deaths by cancer',
#     'Anti-cancer',
#     'Cancer (disease)',
#     'Cancerophobia',
#     'Malignant lesion',
#     'Cancer medication',
#     'Malignant tumors',
#     'Cancer signs',
#     'Malignant neoplasm',
#     'Invasive (cancer)',
#     'Malignant Neoplasms',
#     'Malignant growth',
#     'Sporadic cancer',
#     'Malignant cancer',
#     'Tumour virus',
#     'Cancer en cuirasse',
#     'Microtumor',
#     'Malignant neoplasms',
#     'Malignant tumour',
#     'Carcinophobia',
#     'Malignacy',
#     'Cancer patient',
#     'Epithelial cancers',
#     'Solid cancer',
#     'Cancers',
#     'Tumor medication',
#     'Malignant neoplastic disease',
#     'AIDS-related cancer',
#     'Invasive cancer',
#     'Cancer therapy',
#     'Cancerous tumor',
#     'Cancer',
#     'Financial toxicity',
#     'Cancer diagnosis',
#     'Cancer (medicine)',
#     'Malignant tumor',
#     'Cancerous',
#     'Borderline (cancer)',
#     'Signs of cancer',
#     'Malignancies',
#     'Cancer aromatase'],
#    'MatchedWikiEntityName': 'Cancer',
#    'NormalizedAliases': ['aids related cancer',
#     'sporadic cancer',
#     'cancer disease',
#     'malignant tumors',
#     'cancers',
#     'carcinophobia',
#     'cancer',
#     'cancer diagnosis',
#     'malignant neoplastic disease',
#     'malignant neoplasm',
#     'tumour virus',
#     'cancer medicine',
#     'deaths by cancer',
#     'malignant tumour',
#     'epithelial cancers',
#     'solid cancer',
#     'cancerous',
#     'borderline cancer',
#     'invasive cancer',
#     'anti cancer',
#     'cancer pathology',
#     'cancer signs',
#     'cancer aromatase',
#     'cancer therapy',
#     'financial toxicity',
#     'cancerophobia',
#     'cancer en cuirasse',
#     'cancer patient',
#     'cancerous tumor',
#     'malignant cancer',
#     'malignant neoplasms',
#     'tumor medication',
#     'signs of cancer',
#     'malignacy',
#     'malignant tumor',
#     'cancer medication',
#     'microtumor',
#     'malignancies',
#     'malignant lesion',
#     'malignant growth'],
#    'NormalizedMatchedWikiEntityName': 'cancer',
#    'NormalizedValue': 'cancer',
#    'Type': 'WikipediaEntity',
#    'Value': 'Cancer'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Kathleen_Ferrier.txt',
#     'Title': 'Kathleen Ferrier'}],
#   'Question': 'What claimed the life of singer Kathleen Ferrier?',
#   'QuestionId': 'tc_56',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'claim life singer kathleen ferrier'},
#  {'Answer': {'Aliases': ['Bacall',
#     'Lauren Becal',
#     'Lauren Bacall',
#     'Lauren Becall',
#     'Betty J. Perske',
#     'Loren Bacall',
#     'Betty Joan Perske',
#     'Betty Perske',
#     'Betty Joan Perski'],
#    'MatchedWikiEntityName': 'Lauren Bacall',
#    'NormalizedAliases': ['lauren becall',
#     'loren bacall',
#     'lauren becal',
#     'lauren bacall',
#     'betty j perske',
#     'betty perske',
#     'betty joan perske',
#     'bacall',
#     'betty joan perski'],
#    'NormalizedMatchedWikiEntityName': 'lauren bacall',
#    'NormalizedValue': 'lauren bacall',
#    'Type': 'WikipediaEntity',
#    'Value': 'Lauren Bacall'},
#   'EntityPages': [{'DocSource': 'Search',
#     'Filename': 'Lauren_Bacall.txt',
#     'Title': 'Lauren Bacall',
#     'originalUrl': 'https://www.wikipedia.org/search-redirect.php?family=wikipedia&search=bacall&language=en&go=++%E2%86%92++&go=Go'}],
#   'Question': 'Which actress was voted Miss Greenwich Village in 1942?',
#   'QuestionId': 'tc_106',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'actress vote miss greenwich villag 1942'},
#  {'Answer': {'Aliases': ['Walk on the Moon',
#     'Walk on the moon',
#     'Moonwalk (disambiguation)',
#     'Lunar walks',
#     'Moonwalk',
#     'Moon Walk',
#     'Moonwalking',
#     'Lunar walk',
#     'Moon walk',
#     'Moonwalks',
#     'Moon walks',
#     'Lunar walking',
#     'Moon walking'],
#    'MatchedWikiEntityName': 'Moonwalk',
#    'NormalizedAliases': ['moon walk',
#     'lunar walks',
#     'moonwalks',
#     'moonwalk disambiguation',
#     'lunar walking',
#     'moonwalking',
#     'lunar walk',
#     'walk on moon',
#     'moon walks',
#     'moon walking',
#     'moonwalk'],
#    'NormalizedMatchedWikiEntityName': 'moonwalk',
#    'NormalizedValue': 'moonwalk',
#    'Type': 'WikipediaEntity',
#    'Value': 'Moonwalk'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Michael_Jackson.txt',
#     'Title': 'Michael Jackson'}],
#   'Question': "What was the name of Michael Jackson's autobiography written in 1988?",
#   'QuestionId': 'tc_137',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'name michael jackson autobiographi write 1988'},
#  {'Answer': {'Aliases': ['Mawensi',
#     'Mt. Kilimanjaro',
#     'Kibo (volcano)',
#     'Mount killimanjaro',
#     'Highest mountain in Africa',
#     'Kilimanjaro Massif',
#     'Stella Point',
#     'Kilimandjaro',
#     'Kilimonjaro',
#     'Kilimanjaro',
#     "Gilman's Point",
#     'Killimanjaro',
#     'Kilima-Njaro',
#     'Kiliminjaro',
#     'Mt Kilimanjaro',
#     'Kilimanjaro Mountain',
#     'Mount Kilimanjaro',
#     'Mawenzi',
#     'Uhuru Peak',
#     'Kilimanjiro',
#     'Kaiser-Wilhelm-Spitze',
#     'Mt Kilamanjaro',
#     'Mount Kiliminjaro',
#     'Mount Kilimandjaro',
#     'Mount Kilamanjaro',
#     'Tussock Grassland (Tanzania)',
#     'Kilamanjaro'],
#    'MatchedWikiEntityName': 'Mount Kilimanjaro',
#    'NormalizedAliases': ['mawensi',
#     'kilimanjaro',
#     'mount killimanjaro',
#     'mount kilimanjaro',
#     'mount kilamanjaro',
#     'tussock grassland tanzania',
#     'mt kilamanjaro',
#     'mount kilimandjaro',
#     'kilamanjaro',
#     'kibo volcano',
#     'kilimanjaro massif',
#     'uhuru peak',
#     'kilimanjaro mountain',
#     'kaiser wilhelm spitze',
#     'gilman s point',
#     'mt kilimanjaro',
#     'kilima njaro',
#     'stella point',
#     'mawenzi',
#     'mount kiliminjaro',
#     'kilimandjaro',
#     'killimanjaro',
#     'kilimanjiro',
#     'kilimonjaro',
#     'highest mountain in africa',
#     'kiliminjaro'],
#    'NormalizedMatchedWikiEntityName': 'mount kilimanjaro',
#    'NormalizedValue': 'kilimanjaro',
#    'Type': 'WikipediaEntity',
#    'Value': 'Kilimanjaro'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Tanzania.txt',
#     'Title': 'Tanzania'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Mount_Kilimanjaro.txt',
#     'Title': 'Mount Kilimanjaro'}],
#   'Question': 'Which volcano in Tanzania is the highest mountain in Africa?',
#   'QuestionId': 'tc_217',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'volcano tanzania high mountain africa'},
#  {'Answer': {'Aliases': ['Greenishly',
#     'Avacado (color)',
#     'Green (color)',
#     'Rgb(0, 255, 0)',
#     'Greenishness',
#     'The colour green',
#     'Greenest',
#     'List of terms associated with the color green',
#     'The color green',
#     'Green',
#     'Pastel green',
#     '(0, 255, 0)',
#     'Green (colour)',
#     'Greenness'],
#    'MatchedWikiEntityName': 'Green',
#    'NormalizedAliases': ['greenishness',
#     'color green',
#     '0 255 0',
#     'green color',
#     'green',
#     'rgb 0 255 0',
#     'avacado color',
#     'greenest',
#     'list of terms associated with color green',
#     'greenness',
#     'greenishly',
#     'colour green',
#     'pastel green',
#     'green colour'],
#    'NormalizedMatchedWikiEntityName': 'green',
#    'NormalizedValue': 'green',
#    'Type': 'WikipediaEntity',
#    'Value': 'Green'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Flag_of_Libya.txt',
#     'Title': 'Flag of Libya'},
#    {'DocSource': 'Search',
#     'Filename': 'Flag.txt',
#     'Title': 'Flag',
#     'originalUrl': 'https://pam.wikipedia.org/wiki/Flag'}],
#   'Question': 'The flag of Libya is a plain rectangle of which color?',
#   'QuestionId': 'tc_219',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'flag libya plain rectangl color'},
#  {'Answer': {'Aliases': ['Niger Republic',
#     'Nigerois',
#     'Republic Of Niger',
#     'Republic of Niger',
#     'The Republic of Niger',
#     'Nigerien',
#     'Niger (country)',
#     'République du Niger',
#     'Republique du Niger',
#     'ISO 3166-1:NE',
#     'Niger',
#     'NG-NI'],
#    'MatchedWikiEntityName': 'Niger',
#    'NormalizedAliases': ['niger',
#     'iso 3166 1 ne',
#     'nigerien',
#     'republic of niger',
#     'niger country',
#     'ng ni',
#     'republique du niger',
#     'niger republic',
#     'nigerois',
#     'république du niger'],
#    'NormalizedMatchedWikiEntityName': 'niger',
#    'NormalizedValue': 'niger',
#    'Type': 'WikipediaEntity',
#    'Value': 'Niger'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Niamey.txt',
#     'Title': 'Niamey'}],
#   'Question': 'Of which African country is Niamey the capital?',
#   'QuestionId': 'tc_241',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'african countri niamey capit'},
#  {'Answer': {'Aliases': ['My Fair Lady (2010 film)',
#     'Enry Iggins',
#     "Why Can't the English%3F",
#     'My Fair Lady',
#     'My Fair Lady (upcoming film)',
#     'My Fair Lady (musical)',
#     'My fair lady',
#     "I'm an Ordinary Man",
#     'My Fair Lady (2014 film)',
#     'My Fair Lady (2012 film)',
#     'My Fair Lady (2015 film)'],
#    'MatchedWikiEntityName': 'My Fair Lady',
#    'NormalizedAliases': ['my fair lady musical',
#     'my fair lady',
#     'my fair lady 2010 film',
#     'why can t english 3f',
#     'my fair lady upcoming film',
#     'my fair lady 2012 film',
#     'my fair lady 2014 film',
#     'my fair lady 2015 film',
#     'i m ordinary man',
#     'enry iggins'],
#    'NormalizedMatchedWikiEntityName': 'my fair lady',
#    'NormalizedValue': 'my fair lady',
#    'Type': 'WikipediaEntity',
#    'Value': 'My Fair Lady'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Musical_theatre.txt',
#     'Title': 'Musical theatre'},
#    {'DocSource': 'TagMe',
#     'Filename': 'On_the_Street_Where_You_Live.txt',
#     'Title': 'On the Street Where You Live'}],
#   'Question': 'Which musical featured the song The Street Where You Live?',
#   'QuestionId': 'tc_261',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'music featur song street live'},
#  {'Answer': {'Aliases': ['Hitlerian',
#     'Adolph Schicklgruber',
#     'HitlerAdolf',
#     "Hitler's medical health",
#     'Adolf Hitle',
#     'Hitlar',
#     'Adolph Hiedler',
#     'Adolf Hiedler',
#     'Adolph Hittler',
#     'Day of Potsdam',
#     'Adolpf Hitler',
#     'Adolf Hister',
#     'Adolf Hitlier',
#     "Adolph Hitler's health",
#     "Hitler's health",
#     'Hitlers',
#     'Aldof Hilter',
#     'HITLER',
#     'Hitler, Adolph',
#     'History of Adolf Hitler',
#     'Hitler,Adolph',
#     'Adolph Hiter',
#     'Adolf Hittler',
#     'Herr Hitler',
#     'Hitler,Adolf',
#     'Adolf Schicklegruber',
#     'Adolf hitler',
#     'Adlof hitler',
#     'Adolph Schickelgruber',
#     'Hitler Adolf',
#     'Hitlers medical health',
#     'HitlerAdolph',
#     'Adolph Schicklegruber',
#     'Adolf Hiler',
#     "Adolf Hitler's medical condition",
#     'Hittler',
#     'Adolf Schickelgruber',
#     'Adolf Hitler',
#     "Hitler's",
#     'Hitler, adolf',
#     'Nazi leader',
#     'Hitler, Adolf',
#     'Herr Wolf',
#     "Adolph Hitler's medical health",
#     'Adolph Hitler',
#     "Adolf Hitler's health",
#     'Adolf Schicklgruber',
#     'AdolphHitler',
#     'Adolf Hilter',
#     'Health of Adolf Hitler',
#     "Adolf Hitler's medical health",
#     'Hitler Adolph',
#     'AdolfHitler',
#     'Adolf HItler',
#     'Hitlet',
#     'Hitler adolf',
#     'Adoff Hitler',
#     'Adolfus Hitler',
#     'Hitler',
#     'Adolph hitler'],
#    'MatchedWikiEntityName': 'Adolf Hitler',
#    'NormalizedAliases': ['hitler s medical health',
#     'adlof hitler',
#     'adolf hiedler',
#     'hitler adolf',
#     'hitleradolf',
#     'adolpf hitler',
#     'history of adolf hitler',
#     'hitleradolph',
#     'adolphhitler',
#     'adolf hitler s health',
#     'adoff hitler',
#     'hitlar',
#     'adolf hiler',
#     'adolph hiedler',
#     'adolf hitle',
#     'aldof hilter',
#     'adolph hiter',
#     'hitler s',
#     'hitler',
#     'adolf hister',
#     'adolf hittler',
#     'nazi leader',
#     'adolfhitler',
#     'adolf hitler s medical health',
#     'hitler adolph',
#     'hitler s health',
#     'herr hitler',
#     'adolfus hitler',
#     'adolph hitler',
#     'adolph schicklegruber',
#     'adolf hilter',
#     'adolf hitler s medical condition',
#     'health of adolf hitler',
#     'hitlerian',
#     'adolph schicklgruber',
#     'adolph hitler s medical health',
#     'adolph hitler s health',
#     'adolph schickelgruber',
#     'adolf schicklgruber',
#     'day of potsdam',
#     'adolf hitlier',
#     'adolf hitler',
#     'hitlers medical health',
#     'hittler',
#     'hitlers',
#     'herr wolf',
#     'hitlet',
#     'adolf schickelgruber',
#     'adolf schicklegruber',
#     'adolph hittler'],
#    'NormalizedMatchedWikiEntityName': 'adolf hitler',
#    'NormalizedValue': 'hitler',
#    'Type': 'WikipediaEntity',
#    'Value': 'Hitler'},
#   'EntityPages': [{'DocSource': 'Search',
#     'Filename': '20_July_plot.txt',
#     'Title': '20 July plot',
#     'originalUrl': 'https://en.wikipedia.org/wiki/20_July_plot'}],
#   'Question': '"Who was the target of the failed ""Bomb Plot"" of 1944?"',
#   'QuestionId': 'tc_267',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'target fail bomb plot 1944'},
#  {'Answer': {'Aliases': ['Richard Noel Marx', 'Richard Marx'],
#    'MatchedWikiEntityName': 'Richard Marx',
#    'NormalizedAliases': ['richard marx', 'richard noel marx'],
#    'NormalizedMatchedWikiEntityName': 'richard marx',
#    'NormalizedValue': 'richard marx',
#    'Type': 'WikipediaEntity',
#    'Value': 'Richard Marx'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Hold_On_to_the_Nights.txt',
#     'Title': 'Hold On to the Nights'}],
#   'Question': 'Who had an 80s No 1 hit with Hold On To The Nights?',
#   'QuestionId': 'tc_276',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': '80 1 hit hold night'},
#  {'Answer': {'Aliases': ['John Ford (1895-1973)',
#     "Sean O'Feeney",
#     'John Ford (film director)',
#     'Ford, John (1895-1973)',
#     'Argosy Pictures',
#     'John Ford statue',
#     "John Martin O'Feeney",
#     'John Ford (director)',
#     'Cavalry trilogy',
#     "John O'Feeney",
#     "Sean Aloysius O'Feeney",
#     'Ford, John',
#     'John Ford'],
#    'MatchedWikiEntityName': 'John Ford',
#    'NormalizedAliases': ['john ford 1895 1973',
#     'sean o feeney',
#     'ford john 1895 1973',
#     'john ford statue',
#     'ford john',
#     'john o feeney',
#     'john ford',
#     'sean aloysius o feeney',
#     'argosy pictures',
#     'cavalry trilogy',
#     'john ford film director',
#     'john ford director',
#     'john martin o feeney'],
#    'NormalizedMatchedWikiEntityName': 'john ford',
#    'NormalizedValue': 'john ford',
#    'Type': 'WikipediaEntity',
#    'Value': 'John Ford'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Stagecoach_(1939_film).txt',
#     'Title': 'Stagecoach (1939 film)'}],
#   'Question': 'Who directed the classic 30s western Stagecoach?',
#   'QuestionId': 'tc_280',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'direct classic 30 western stagecoach'},
#  {'Answer': {'Aliases': ['Grey Floyd',
#     'Pink Floyd trivia',
#     'The Screaming Ab Dabs',
#     'Pink flowd',
#     'The Meggadeaths',
#     'The Architectural Abdabs',
#     'PINK FLOYD',
#     'Pink Flod',
#     'Pink Floyd',
#     'Pink Floyd Trivia',
#     'The Pink Floyd',
#     'Notable or frequent contributors to pink floyd',
#     'The Tea Set',
#     'Pinkfloyd',
#     'Pi5',
#     'Pink floid',
#     'Pink Floyd (band)',
#     'The T Set',
#     'Screaming abdabs',
#     'Notable or frequent contributors to Pink Floyd',
#     'The Megadeaths',
#     'Pik floyd',
#     'The Pink Floyd Sound',
#     'Pink floyd',
#     'The T-Set',
#     'The Screaming Abdabs',
#     'Clive Metcalfe',
#     'Meggadeaths'],
#    'MatchedWikiEntityName': 'Pink Floyd',
#    'NormalizedAliases': ['screaming abdabs',
#     'megadeaths',
#     'clive metcalfe',
#     'pink floyd band',
#     'pink flowd',
#     'meggadeaths',
#     'pi5',
#     'pink floyd',
#     'screaming ab dabs',
#     'grey floyd',
#     'architectural abdabs',
#     'pink flod',
#     'pinkfloyd',
#     'pik floyd',
#     'pink floyd sound',
#     'tea set',
#     'pink floid',
#     't set',
#     'pink floyd trivia',
#     'notable or frequent contributors to pink floyd'],
#    'NormalizedMatchedWikiEntityName': 'pink floyd',
#    'NormalizedValue': 'pink floyd',
#    'Type': 'WikipediaEntity',
#    'Value': 'Pink Floyd'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Roger_Waters.txt',
#     'Title': 'Roger Waters'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Rock_music.txt',
#     'Title': 'Rock music'}],
#   'Question': 'Dave Gilmore and Roger Waters were in which rock group?',
#   'QuestionId': 'tc_282',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'dave gilmor roger water rock group'},
#  {'Answer': {'Aliases': ['61', 'sixty-one'],
#    'Multiplier': '',
#    'NormalizedAliases': ['61', 'sixty one'],
#    'NormalizedValue': '61',
#    'Number': '61',
#    'Type': 'Numerical',
#    'Unit': '',
#    'Value': '61'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Bob_Dylan.txt',
#     'Title': 'Bob Dylan'}],
#   'Question': 'Which highway was Revisited in a classic 60s album by Bob Dylan?',
#   'QuestionId': 'tc_288',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'highway revisit classic 60 album bob dylan'},
#  {'Answer': {'Aliases': ['ISO 3166-1:RO',
#     'Romanian state',
#     'ROMANIA',
#     'Roumania',
#     'Etymology of Romania',
#     'Romainia',
#     'Romînia',
#     'North Danubian region',
#     'Carpathian Danubian space',
#     'ROU',
#     'România',
#     'Romanian State',
#     'Roumanie',
#     'Country ROM',
#     'Rromania',
#     'Romania',
#     'Republic of Romania',
#     'RO (country)',
#     'Rumänien',
#     'Danubian-Carpathian Area',
#     'Rumania',
#     'Austro-Hungarian Empire (Romania)',
#     'Rumunia'],
#    'MatchedWikiEntityName': 'Romania',
#    'NormalizedAliases': ['danubian carpathian area',
#     'roumania',
#     'austro hungarian empire romania',
#     'romania',
#     'rromania',
#     'iso 3166 1 ro',
#     'rou',
#     'country rom',
#     'ro country',
#     'rumunia',
#     'romainia',
#     'rumänien',
#     'etymology of romania',
#     'north danubian region',
#     'romînia',
#     'rumania',
#     'romanian state',
#     'carpathian danubian space',
#     'românia',
#     'republic of romania',
#     'roumanie'],
#    'NormalizedMatchedWikiEntityName': 'romania',
#    'NormalizedValue': 'rumania',
#    'Type': 'WikipediaEntity',
#    'Value': 'Rumania'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Eastern_Bloc.txt',
#     'Title': 'Eastern Bloc'},
#    {'DocSource': 'TagMe',
#     'Filename': '1984_Summer_Olympics.txt',
#     'Title': '1984 Summer Olympics'},
#    {'DocSource': 'Search',
#     'Filename': '1984_Summer_Olympics_boycott.txt',
#     'Title': '1984 Summer Olympics boycott',
#     'originalUrl': 'https://en.wikipedia.org/wiki/1984_Summer_Olympics_boycott'}],
#   'Question': 'Which was the only eastern bloc country to participate in the 1984 LA Olympics?',
#   'QuestionId': 'tc_298',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'eastern bloc countri particip 1984 la olymp'},
#  {'Answer': {'Aliases': ['Wild Palms'],
#    'MatchedWikiEntityName': 'Wild Palms',
#    'NormalizedAliases': ['wild palms'],
#    'NormalizedMatchedWikiEntityName': 'wild palms',
#    'NormalizedValue': 'wild palms',
#    'Type': 'WikipediaEntity',
#    'Value': 'Wild Palms'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Jim_Belushi.txt',
#     'Title': 'Jim Belushi'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Bruce_Wagner.txt',
#     'Title': 'Bruce Wagner'},
#    {'DocSource': 'Search',
#     'Filename': 'Wild_Palms.txt',
#     'Title': 'Wild Palms',
#     'originalUrl': 'https://en.wikipedia.org/wiki/Wild_Palms'}],
#   'Question': "Which 90s sci fi series with James Belushi was based on Bruce Wagner's comic strip of the same name?",
#   'QuestionId': 'tc_304',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': '90 sci fi seri jame belushi base bruce wagner comic strip name'},
#  {'Answer': {'Aliases': ['Fiddler on a Roof',
#     'Fiddler on the roof',
#     'Sprintze',
#     'Fiddler On the Roof',
#     '2 life',
#     'Fiddler On The Roof',
#     'The Fiddler on the Roof',
#     'Fiddler on the Roof',
#     'Fiddler on the reoof',
#     'Anatevka'],
#    'MatchedWikiEntityName': 'Fiddler on the Roof',
#    'NormalizedAliases': ['fiddler on roof',
#     'sprintze',
#     'anatevka',
#     '2 life',
#     'fiddler on reoof'],
#    'NormalizedMatchedWikiEntityName': 'fiddler on roof',
#    'NormalizedValue': 'fiddler on roof',
#    'Type': 'WikipediaEntity',
#    'Value': 'Fiddler on the Roof'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'If_I_Were_a_Rich_Man_(song).txt',
#     'Title': 'If I Were a Rich Man (song)'}],
#   'Question': 'If I Were A Rich Man Was a big hit from which stage show?',
#   'QuestionId': 'tc_316',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'rich man big hit stage show'},
#  {'Answer': {'Aliases': ['HMS Bounty mutineers',
#     'Mutiny on the Bounty',
#     'Mutiny on Bounty',
#     'Mutiny On The Bounty',
#     'Mutiny on the Bounty (history)',
#     'Mutiny on the bounty',
#     'Bounty (vessel)',
#     'Thomas Ledward'],
#    'MatchedWikiEntityName': 'Mutiny on the Bounty',
#    'NormalizedAliases': ['mutiny on bounty history',
#     'hms bounty mutineers',
#     'bounty vessel',
#     'mutiny on bounty',
#     'thomas ledward'],
#    'NormalizedMatchedWikiEntityName': 'mutiny on bounty',
#    'NormalizedValue': 'mutiny on bounty',
#    'Type': 'WikipediaEntity',
#    'Value': 'Mutiny On The Bounty'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Men_Against_the_Sea.txt',
#     'Title': 'Men Against the Sea'},
#    {'DocSource': 'TagMe',
#     'Filename': "Pitcairn's_Island_(novel).txt",
#     'Title': "Pitcairn's Island (novel)"}],
#   'Question': "Men Against the Sea and Pitcairn's Island were two sequels to what famous novel?",
#   'QuestionId': 'tc_349',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'man sea pitcairn island two sequel famou novel'},
#  {'Answer': {'Aliases': ['Perſons',
#     'Person',
#     'Person (philosophical)',
#     'Personhood Theory',
#     'Persons',
#     'Perſon',
#     'A person',
#     'Personhood theory'],
#    'MatchedWikiEntityName': 'Person',
#    'NormalizedAliases': ['personhood theory',
#     'persons',
#     'person',
#     'perſon',
#     'perſons',
#     'person philosophical'],
#    'NormalizedMatchedWikiEntityName': 'person',
#    'NormalizedValue': 'persons',
#    'Type': 'WikipediaEntity',
#    'Value': 'Persons'},
#   'EntityPages': [{'DocSource': 'Search',
#     'Filename': 'Truman_Capote.txt',
#     'Title': 'Truman Capote',
#     'originalUrl': 'https://en.wikipedia.org/wiki/Truman_Capote'}],
#   'Question': "What was Truman Capote's last name before he was adopted by his stepfather?",
#   'QuestionId': 'tc_379',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'truman capot last name adopt stepfath'},
#  {'Answer': {'Aliases': ['Boojum (disambiguation)', 'A boojum', 'Boojum'],
#    'MatchedWikiEntityName': 'Boojum',
#    'NormalizedAliases': ['boojum disambiguation', 'boojum'],
#    'NormalizedMatchedWikiEntityName': 'boojum',
#    'NormalizedValue': 'boojum',
#    'Type': 'WikipediaEntity',
#    'Value': 'A boojum'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'The_Hunting_of_the_Snark.txt',
#     'Title': 'The Hunting of the Snark'}],
#   'Question': "In Lewis Carroll's poem The Hunting of the Snark, what did the elusive, troublesome snark turn into to fool hunters?",
#   'QuestionId': 'tc_397',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'lewi carrol poem hunt snark elus troublesom snark turn fool hunter'},
#  {'Answer': {'Aliases': ['Dangerous Minds (film)',
#     "My Posse Don't Do Homework",
#     'Dangerous Minds'],
#    'MatchedWikiEntityName': 'Dangerous Minds',
#    'NormalizedAliases': ['my posse don t do homework',
#     'dangerous minds',
#     'dangerous minds film'],
#    'NormalizedMatchedWikiEntityName': 'dangerous minds',
#    'NormalizedValue': 'dangerous minds',
#    'Type': 'WikipediaEntity',
#    'Value': 'Dangerous Minds'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Michelle_Pfeiffer.txt',
#     'Title': 'Michelle Pfeiffer'},
#    {'DocSource': 'TagMe', 'Filename': 'Coolio.txt', 'Title': 'Coolio'},
#    {'DocSource': 'TagMe',
#     'Filename': "Gangsta's_Paradise.txt",
#     'Title': "Gangsta's Paradise"},
#    {'DocSource': 'Search',
#     'Filename': 'Dangerous_Minds.txt',
#     'Title': 'Dangerous Minds',
#     'originalUrl': 'https://en.wikipedia.org/wiki/Dangerous_Minds'}],
#   'Question': "What Michelle Pfeiffer movie got a boost from the Coolio song Gangsta's Paradise?",
#   'QuestionId': 'tc_455',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'michel pfeiffer movi get boost coolio song gangsta paradis'},
#  {'Answer': {'Aliases': ['Rudolph (disambiguation)',
#     'Rudolph',
#     'Rudolf',
#     'Rodolph',
#     'Rodolphe'],
#    'MatchedWikiEntityName': 'Rudolph',
#    'NormalizedAliases': ['rudolf',
#     'rudolph',
#     'rodolphe',
#     'rudolph disambiguation',
#     'rodolph'],
#    'NormalizedMatchedWikiEntityName': 'rudolph',
#    'NormalizedValue': 'rudolph',
#    'Type': 'WikipediaEntity',
#    'Value': 'Rudolph'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Gerald_Ford.txt',
#     'Title': 'Gerald Ford'}],
#   'Question': "What was President Gerald Ford's middle name?",
#   'QuestionId': 'tc_510',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'presid gerald ford middl name'},
#  {'Answer': {'Aliases': ['Master Builder (occupation)',
#     'Master builder (occupation)',
#     'Registered Architect',
#     'Architects',
#     'Architecht',
#     'Architect',
#     'HOK Canada, Inc.',
#     'Stanford Downey Architects Inc.',
#     'Graziani + Corazza',
#     'Architechts',
#     'Clifford & Lawrie'],
#    'MatchedWikiEntityName': 'Architect',
#    'NormalizedAliases': ['master builder occupation',
#     'graziani corazza',
#     'architecht',
#     'clifford lawrie',
#     'architechts',
#     'architects',
#     'registered architect',
#     'hok canada inc',
#     'architect',
#     'stanford downey architects inc'],
#    'NormalizedMatchedWikiEntityName': 'architect',
#    'NormalizedValue': 'architect',
#    'Type': 'WikipediaEntity',
#    'Value': 'Architect'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Art_Garfunkel.txt',
#     'Title': 'Art Garfunkel'}],
#   'Question': "Art Garfunkel trained for which profession although he didn't qualify?",
#   'QuestionId': 'tc_515',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'art garfunkel train profess although qualifi'},
#  {'Answer': {'Aliases': ['Hess, Rudolf',
#     'Rudolf hess',
#     'Rudolf W. Hess',
#     'Rudolph Hess',
#     'Walther Richard Rudolf Hess',
#     'Rudolf Walter Richard Hess',
#     'Rudolf Hess',
#     'Rudolf Walter Richard Heß',
#     'Rudolph Heß',
#     'Rudolf Heß',
#     'Rudolf Hesse'],
#    'MatchedWikiEntityName': 'Rudolf Hess',
#    'NormalizedAliases': ['rudolf hesse',
#     'hess rudolf',
#     'walther richard rudolf hess',
#     'rudolf hess',
#     'rudolf w hess',
#     'rudolf walter richard heß',
#     'rudolf walter richard hess',
#     'rudolph heß',
#     'rudolf heß',
#     'rudolph hess'],
#    'NormalizedMatchedWikiEntityName': 'rudolf hess',
#    'NormalizedValue': 'rudolf hess',
#    'Type': 'WikipediaEntity',
#    'Value': 'Rudolf Hess'},
#   'EntityPages': [{'DocSource': 'Search',
#     'Filename': 'Spandau_Prison.txt',
#     'Title': 'Spandau Prison',
#     'originalUrl': 'https://simple.wikipedia.org/wiki/Spandau_Prison'}],
#   'Question': 'Who was the last inmate of Spandau jail in Berlin?',
#   'QuestionId': 'tc_517',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'last inmat spandau jail berlin'},
#  {'Answer': {'Aliases': ['JG Ballard',
#     'J.G. Ballard',
#     'James Graham Ballard',
#     'J. G. Ballard',
#     'J.G.Ballard',
#     'Jg ballard',
#     "A User's Guide to the Millenium",
#     'J G Ballard',
#     'Ballardian',
#     'James G. Ballard'],
#    'MatchedWikiEntityName': 'J. G. Ballard',
#    'NormalizedAliases': ['ballardian',
#     'user s guide to millenium',
#     'james g ballard',
#     'j g ballard',
#     'jg ballard',
#     'james graham ballard'],
#    'NormalizedMatchedWikiEntityName': 'j g ballard',
#    'NormalizedValue': 'j g ballard',
#    'Type': 'WikipediaEntity',
#    'Value': 'J. G. Ballard'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Empire_of_the_Sun_(band).txt',
#     'Title': 'Empire of the Sun (band)'},
#    {'DocSource': 'Search',
#     'Filename': 'Empire_of_the_Sun.txt',
#     'Title': 'Empire of the Sun',
#     'originalUrl': 'https://en.wikipedia.org/wiki/Empire_of_the_Sun'}],
#   'Question': 'In the 80s who wrote the novel Empire of The Sun?',
#   'QuestionId': 'tc_538',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': '80 write novel empir sun'},
#  {'Answer': {'Aliases': ['日本國',
#     'State of Japan',
#     'Ja-pan',
#     'Nihon',
#     'Nippon',
#     'Japang',
#     'Modern–era Japan',
#     'Etymology of Japan',
#     'Japan (country)',
#     'Republic of Japan',
#     'Japanese financial sector',
#     'Nihon-koku',
#     'ISO 3166-1:JP',
#     '日本',
#     'Japian',
#     'Japan',
#     'JapaN',
#     'The State of Japan',
#     'Riben',
#     'Nippon-koku',
#     'JPN',
#     'Jpan',
#     'Rìběn',
#     '日本国',
#     'Japao',
#     'JAPAN',
#     'Japoa',
#     '🗾'],
#    'MatchedWikiEntityName': 'Japan',
#    'NormalizedAliases': ['nihon koku',
#     'nihon',
#     'japoa',
#     'japang',
#     'japan',
#     '日本國',
#     'etymology of japan',
#     'iso 3166 1 jp',
#     'jpan',
#     'japan country',
#     'riben',
#     'rìběn',
#     '🗾',
#     'japanese financial sector',
#     'japian',
#     'nippon koku',
#     'state of japan',
#     'nippon',
#     'modern–era japan',
#     'republic of japan',
#     '日本国',
#     'jpn',
#     'japao',
#     'ja pan',
#     '日本'],
#    'NormalizedMatchedWikiEntityName': 'japan',
#    'NormalizedValue': 'japan',
#    'Type': 'WikipediaEntity',
#    'Value': 'Japan'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Kagoshima_Airport.txt',
#     'Title': 'Kagoshima Airport'},
#    {'DocSource': 'TagMe', 'Filename': 'Airport.txt', 'Title': 'Airport'}],
#   'Question': 'Kagoshima international airport is in which country?',
#   'QuestionId': 'tc_540',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'kagoshima intern airport countri'},
#  {'Answer': {'Aliases': ['Basketball',
#     'Basketball gear',
#     'Bball',
#     "Boy's Basketball",
#     'B Ball',
#     'Shoot hoops',
#     'Basketball parity worldwide',
#     "Men's Basketball",
#     'High school basketball',
#     'Basketball Worldwide',
#     'Basketball club',
#     'B-ball',
#     'Basket-ball',
#     'Basketball team',
#     '🏀',
#     'Basketball rim',
#     'Basketballer',
#     'Rim (basketball)',
#     'Basket ball',
#     'Basketball net',
#     'Baksetball',
#     'Basketball player',
#     'Basket-Ball',
#     'A: Basketball',
#     "Women's hoops",
#     "Men's basketball",
#     'BasketBall',
#     'Basketball Parity Worldwide',
#     'Basket Ball',
#     'Baketball',
#     'Basketball Player',
#     'B ball',
#     'Unicycle basketball'],
#    'MatchedWikiEntityName': 'Basketball',
#    'NormalizedAliases': ['men s basketball',
#     'baksetball',
#     'baketball',
#     'boy s basketball',
#     'basketball club',
#     'high school basketball',
#     'rim basketball',
#     'basketball team',
#     'bball',
#     'unicycle basketball',
#     'basketball worldwide',
#     'shoot hoops',
#     'b ball',
#     'basketball',
#     'basketball net',
#     'women s hoops',
#     'basketball gear',
#     'basketballer',
#     'basket ball',
#     'basketball rim',
#     '🏀',
#     'basketball parity worldwide',
#     'basketball player'],
#    'NormalizedMatchedWikiEntityName': 'basketball',
#    'NormalizedValue': 'basketball',
#    'Type': 'WikipediaEntity',
#    'Value': 'A: Basketball'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Indiana_Pacers.txt',
#     'Title': 'Indiana Pacers'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Detroit_Pistons.txt',
#     'Title': 'Detroit Pistons'}],
#   'Question': 'In which sport could the Pacers take on the Pistons?',
#   'QuestionId': 'tc_543',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'sport could pacer take piston'},
#  {'Answer': {'Aliases': ['Stars on 45 (Single)',
#     'Stars On 45 Medley',
#     'Stars on 45 medley',
#     'Stars on 45 (song)',
#     'Stars on 45 Medley',
#     "Medley: Intro Venus / Sugar Sugar / No Reply / I'll Be Back / Drive My Car / Do You Want to Know a Secret / We Can Work It Out / I Should Have Known Better / Nowhere Man / You're Going to Lose That Girl / Stars on 45"],
#    'MatchedWikiEntityName': 'Stars on 45 (song)',
#    'NormalizedAliases': ['stars on 45 song',
#     'stars on 45 single',
#     'stars on 45 medley',
#     'medley intro venus sugar sugar no reply i ll be back drive my car do you want to know secret we can work it out i should have known better nowhere man you re going to lose that girl stars on 45'],
#    'NormalizedMatchedWikiEntityName': 'stars on 45 song',
#    'NormalizedValue': 'stars on 45 medley',
#    'Type': 'WikipediaEntity',
#    'Value': 'Stars on 45 medley'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Bette_Davis_Eyes.txt',
#     'Title': 'Bette Davis Eyes'}],
#   'Question': "Kim Carnes' nine weeks at No 1 with Bette Davis Eyes was interrupted for one week by which song?",
#   'QuestionId': 'tc_559',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'kim carn nine week 1 bett davi eye interrupt one week song'},
#  {'Answer': {'Aliases': ['Vancouver, Canada',
#     'Vancouver (Canada)',
#     'Corpus Christi Elementary School (Canada)',
#     'UN/LOCODE:CAVAN',
#     'Vancouver, British Columbia, Canada',
#     'Vancouver, BC, Canada',
#     'Vancouver, British-Columbia',
#     'Vancouver, B.C., Canada',
#     'Vancouver',
#     'Vancouver, British Colombia',
#     'Vancover, British Columbia',
#     'Vansterdam',
#     'Vancouver (BC)',
#     'Hastings East (Vancouver)',
#     'Vancouver British Columbia',
#     'Vancouver Canada',
#     'City of Vancouver',
#     'Vancouver, BC',
#     'Vancouver (B.C.)',
#     'Vancouver City Centre, British Columbia',
#     'Vancouver, B.C.',
#     'South Vancouver, British Columbia',
#     'Vancouverite',
#     'Vancouver, British Columbia',
#     'Vancouver Christian School',
#     'Vancouvr',
#     'Hong kouver',
#     'Vancouverites',
#     'Hongcouver',
#     'Vancouver, bc',
#     'Corpus Christi Elementary',
#     'Hong couver',
#     'Greater Vancouver Bridges',
#     'Vancover',
#     'Vanocuver',
#     'Vancouver BC'],
#    'MatchedWikiEntityName': 'Vancouver',
#    'NormalizedAliases': ['south vancouver british columbia',
#     'vansterdam',
#     'vancouvr',
#     'vancouver bc',
#     'vancover',
#     'vancouver british colombia',
#     'hong kouver',
#     'vancouver',
#     'vancouver bc canada',
#     'vancouverites',
#     'un locode cavan',
#     'vancouver christian school',
#     'vancouver b c canada',
#     'vancouver city centre british columbia',
#     'vanocuver',
#     'vancouver british columbia',
#     'corpus christi elementary',
#     'vancouverite',
#     'hongcouver',
#     'hong couver',
#     'hastings east vancouver',
#     'vancouver canada',
#     'vancover british columbia',
#     'corpus christi elementary school canada',
#     'city of vancouver',
#     'greater vancouver bridges',
#     'vancouver b c',
#     'vancouver british columbia canada'],
#    'NormalizedMatchedWikiEntityName': 'vancouver',
#    'NormalizedValue': 'vancouver',
#    'Type': 'WikipediaEntity',
#    'Value': 'Vancouver'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Canada.txt',
#     'Title': 'Canada'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Lions_Gate_Bridge.txt',
#     'Title': 'Lions Gate Bridge'}],
#   'Question': "Where in Canada is the Lion's Gate bridge?",
#   'QuestionId': 'tc_561',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'canada lion gate bridg'},
#  {'Answer': {'Aliases': ['The Kentuckian'],
#    'MatchedWikiEntityName': 'The Kentuckian',
#    'NormalizedAliases': ['kentuckian'],
#    'NormalizedMatchedWikiEntityName': 'kentuckian',
#    'NormalizedValue': 'kentuckian',
#    'Type': 'WikipediaEntity',
#    'Value': 'The Kentuckian'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Walter_Matthau.txt',
#     'Title': 'Walter Matthau'}],
#   'Question': "What was Walter Matthau's first movie?",
#   'QuestionId': 'tc_564',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'walter matthau first movi'},
#  {'Answer': {'Aliases': ['Cofantre',
#     'Coventry (city)',
#     'Coventry, Warwickshire',
#     'Coventry',
#     'Coventry, UK',
#     'Coventry, England',
#     'City of Coventry',
#     'COVENTRY',
#     'County Borough of Coventry',
#     'Coventry (borough)',
#     'Coventry City council',
#     'Coventry, United Kingdom',
#     'Metropolitan Borough of Coventry'],
#    'MatchedWikiEntityName': 'Coventry',
#    'NormalizedAliases': ['coventry uk',
#     'cofantre',
#     'coventry united kingdom',
#     'coventry borough',
#     'coventry city',
#     'coventry england',
#     'metropolitan borough of coventry',
#     'coventry city council',
#     'coventry',
#     'county borough of coventry',
#     'coventry warwickshire',
#     'city of coventry'],
#    'NormalizedMatchedWikiEntityName': 'coventry',
#    'NormalizedValue': 'coventry',
#    'Type': 'WikipediaEntity',
#    'Value': 'Coventry'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'England.txt',
#     'Title': 'England'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Nigel_Hawthorne.txt',
#     'Title': 'Nigel Hawthorne'}],
#   'Question': 'Where in England was actor Nigel Hawthorne born?',
#   'QuestionId': 'tc_586',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'england actor nigel hawthorn bear'},
#  {'Answer': {'Aliases': ['Cyclopes (disambiguation)', 'Cyclopes'],
#    'MatchedWikiEntityName': 'Cyclopes',
#    'NormalizedAliases': ['cyclopes disambiguation', 'cyclopes'],
#    'NormalizedMatchedWikiEntityName': 'cyclopes',
#    'NormalizedValue': 'cyclopes',
#    'Type': 'WikipediaEntity',
#    'Value': 'Cyclopes'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Greek_mythology.txt',
#     'Title': 'Greek mythology'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Arges_(cyclops).txt',
#     'Title': 'Arges (cyclops)'},
#    {'DocSource': 'TagMe', 'Filename': 'Cyclops.txt', 'Title': 'Cyclops'},
#    {'DocSource': 'Search',
#     'Filename': 'Gaia_(mythology).txt',
#     'Title': 'Gaia (mythology)',
#     'originalUrl': 'https://www.wikipedia.org/wiki/en:Gaia_(mythology)'}],
#   'Question': 'In Greek mythology, who were Arges, Brontes and Steropes?',
#   'QuestionId': 'tc_604',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'greek mytholog arg bront sterop'},
#  {'Answer': {'Aliases': ['Ferdinand Joseph La Menthe',
#     'Louise Monette',
#     'Ferdinand Morton',
#     'Ferdinand %22Jelly Roll%22 Morton',
#     'F.P. Lamothe',
#     'Ferdinand Lamothe',
#     'Jellyroll Morton',
#     'Ferdinand Joseph Morton',
#     'Joseph Ferdinand Morton',
#     'Ferdinand Joseph Lamothe',
#     'Jelly-Roll Morton',
#     'Jelly Roll Morton'],
#    'MatchedWikiEntityName': 'Jelly Roll Morton',
#    'NormalizedAliases': ['ferdinand morton',
#     'jellyroll morton',
#     'joseph ferdinand morton',
#     'f p lamothe',
#     'ferdinand lamothe',
#     'ferdinand joseph la menthe',
#     'ferdinand joseph morton',
#     'ferdinand joseph lamothe',
#     'jelly roll morton',
#     'louise monette',
#     'ferdinand 22jelly roll 22 morton'],
#    'NormalizedMatchedWikiEntityName': 'jelly roll morton',
#    'NormalizedValue': 'jelly roll morton',
#    'Type': 'WikipediaEntity',
#    'Value': 'Jelly Roll Morton'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Red_Hot_Peppers.txt',
#     'Title': 'Red Hot Peppers'}],
#   'Question': 'Which musician founded the Red Hot Peppers?',
#   'QuestionId': 'tc_626',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'musician found red hot pepper'},
#  {'Answer': {'Aliases': ['Lower Peru',
#     'Name of Peru',
#     'Republic of Peru',
#     'Etymology of Peru',
#     'ISO 3166-1:PE',
#     'Piruw',
#     'Peruano',
#     'República del Perú',
#     'El Perú',
#     'Republic of Perú',
#     'Peruvian Republic',
#     'Peru',
#     'Peruvian',
#     'Péru',
#     'Piruw Ripuwlika',
#     'El Peru',
#     'Perú',
#     'Perù',
#     'Piruw Suyu',
#     'Pérou',
#     'Peruvia'],
#    'MatchedWikiEntityName': 'Peru',
#    'NormalizedAliases': ['republic of perú',
#     'piruw suyu',
#     'iso 3166 1 pe',
#     'peruvian republic',
#     'perú',
#     'piruw ripuwlika',
#     'perù',
#     'lower peru',
#     'republic of peru',
#     'el peru',
#     'el perú',
#     'pérou',
#     'peruano',
#     'name of peru',
#     'peruvia',
#     'piruw',
#     'peru',
#     'república del perú',
#     'peruvian',
#     'etymology of peru',
#     'péru'],
#    'NormalizedMatchedWikiEntityName': 'peru',
#    'NormalizedValue': 'peru',
#    'Type': 'WikipediaEntity',
#    'Value': 'Peru'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Shining_Path.txt',
#     'Title': 'Shining Path'}],
#   'Question': 'Where did the Shinning Path terrorists operate?',
#   'QuestionId': 'tc_635',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'shin path terrorist oper'},
#  {'Answer': {'Aliases': ['27', 'twenty-seven'],
#    'Multiplier': '',
#    'NormalizedAliases': ['27', 'twenty seven'],
#    'NormalizedValue': '27',
#    'Number': '27',
#    'Type': 'Numerical',
#    'Unit': '',
#    'Value': '27'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Jimi_Hendrix.txt',
#     'Title': 'Jimi Hendrix'}],
#   'Question': 'How old was Jimi Hendrix when he died?',
#   'QuestionId': 'tc_653',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'old jimi hendrix die'},
#  {'Answer': {'Aliases': ['Richard Noble'],
#    'MatchedWikiEntityName': 'Richard Noble',
#    'NormalizedAliases': ['richard noble'],
#    'NormalizedMatchedWikiEntityName': 'richard noble',
#    'NormalizedValue': 'richard noble',
#    'Type': 'WikipediaEntity',
#    'Value': 'Richard Noble'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Thrust2.txt',
#     'Title': 'Thrust2'},
#    {'DocSource': 'Search',
#     'Filename': 'ThrustSSC.txt',
#     'Title': 'ThrustSSC',
#     'originalUrl': 'https://en.wikipedia.org/wiki/ThrustSSC'}],
#   'Question': 'Which Brit broke the land speed record in 1990 in Thrust 2?',
#   'QuestionId': 'tc_657',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'brit break land speed record 1990 thrust 2'},
#  {'Answer': {'Aliases': ['US-VA',
#     'State of Virginia',
#     'Virginia, USA',
#     'Tenth State',
#     'Religion in Virginia',
#     'Virginia (USA state)',
#     'Virginia (state)',
#     'Commonwealth of VA',
#     'Rest of Virginia',
#     'Virginia',
#     'Mother of Presidents',
#     'Virginia (USA State)',
#     'The Old Dominion',
#     'VA (state)',
#     'Commonwealth of Virginia',
#     'Virginian Commonwealth',
#     'The Mother of Presidents',
#     'Virginia, United States',
#     'Council of Virginia',
#     'Sports in Virginia',
#     'Viginia',
#     'Virginia (U.S. state)',
#     '10th State',
#     'Virgina',
#     'The Commonwealth of Virginia',
#     'VA, USA',
#     'Virginia (State)'],
#    'MatchedWikiEntityName': 'Virginia',
#    'NormalizedAliases': ['commonwealth of virginia',
#     'sports in virginia',
#     'va state',
#     'rest of virginia',
#     'va usa',
#     'virginia usa state',
#     '10th state',
#     'virginian commonwealth',
#     'us va',
#     'tenth state',
#     'viginia',
#     'commonwealth of va',
#     'mother of presidents',
#     'virginia',
#     'virginia united states',
#     'council of virginia',
#     'virginia usa',
#     'virgina',
#     'old dominion',
#     'state of virginia',
#     'religion in virginia',
#     'virginia state',
#     'virginia u s state'],
#    'NormalizedMatchedWikiEntityName': 'virginia',
#    'NormalizedValue': 'virginia',
#    'Type': 'WikipediaEntity',
#    'Value': 'Virginia'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Gene_Vincent.txt',
#     'Title': 'Gene Vincent'}],
#   'Question': 'In which state was Gene Vincent born?',
#   'QuestionId': 'tc_664',
#   'QuestionSource': 'http://www.triviacountry.com/',
#   'Question_preprocessed': 'state gene vincent bear'},
#  {'Answer': {'Aliases': ['European Recovery Programme',
#     'The marshal plan',
#     'Marshall Aid',
#     'European Recovery Program',
#     'Marshall Paln',
#     'The Marshall Plan',
#     'European recovery act',
#     'Marshall aid',
#     'Marshall Plan',
#     'Marshal plan',
#     'Organization for European Economic Recovery',
#     'Ministère de la Reconstruction',
#     'Marshall aid plan',
#     'Economic Cooperation Act of 1948',
#     'Marshall plan',
#     'Operation Rathole'],
#    'MatchedWikiEntityName': 'Marshall Plan',
#    'NormalizedAliases': ['marshall aid plan',
#     'european recovery act',
#     'economic cooperation act of 1948',
#     'marshall aid',
#     'marshal plan',
#     'marshall paln',
#     'european recovery programme',
#     'european recovery program',
#     'organization for european economic recovery',
#     'ministère de la reconstruction',
#     'operation rathole',
#     'marshall plan'],
#    'NormalizedMatchedWikiEntityName': 'marshall plan',
# ...
#     'origami bonsai',
#     '折紙',
#     'oragami',
#     'origaming',
#     'paper folding art',
#     'paper folding',
#     'paperfolding'],
#    'NormalizedMatchedWikiEntityName': 'origami',
#    'NormalizedValue': 'origami',
#    'Type': 'WikipediaEntity',
#    'Value': 'Origami'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Japanese_art.txt',
#     'Title': 'Japanese art'},
#    {'DocSource': 'TagMe', 'Filename': 'Origami.txt', 'Title': 'Origami'}],
#   'Question': 'What is the Japanese art of paper-folding called?',
#   'QuestionId': 'qb_5532',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'japanes art paper fold call'},
#  {'Answer': {'Aliases': ['Sheep',
#     'Ovis aries',
#     'Domestic ram',
#     'Yorkshire Leicester',
#     'Persian Lamb',
#     '🐏',
#     '🐑',
#     'Bleat',
#     'Domesticated sheep',
#     'Ovine',
#     'Domestic ewe',
#     'Domestic sheep',
#     'Sheeps',
#     'Agnine',
#     'Feral sheep',
#     'Domestic Sheep',
#     'Ovis orientalis aries',
#     'Sheep sounds',
#     'Sheep description',
#     'Ram (sheep)',
#     'Yowe',
#     'Sheep, domestic'],
#    'MatchedWikiEntityName': 'Sheep',
#    'NormalizedAliases': ['sheep domestic',
#     'agnine',
#     'sheep sounds',
#     '🐑',
#     '🐏',
#     'domesticated sheep',
#     'persian lamb',
#     'ovis orientalis aries',
#     'ram sheep',
#     'domestic sheep',
#     'ovine',
#     'sheep description',
#     'domestic ewe',
#     'domestic ram',
#     'yorkshire leicester',
#     'ovis aries',
#     'sheeps',
#     'feral sheep',
#     'yowe',
#     'sheep',
#     'bleat'],
#    'NormalizedMatchedWikiEntityName': 'sheep',
#    'NormalizedValue': 'sheep',
#    'Type': 'WikipediaEntity',
#    'Value': 'Sheep'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Haggis.txt',
#     'Title': 'Haggis'}],
#   'Question': 'The stomach of which animal is traditionally stuffed for a haggis?',
#   'QuestionId': 'qb_5538',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'stomach anim tradit stuff haggi'},
#  {'Answer': {'Aliases': ['Asia/Bahrain',
#     'مملكة البحرين',
#     'Bahrein',
#     'Bahrayn',
#     'Dawlat al-Bahrain',
#     'Bahrein Islands',
#     'Etymology of Bahrain',
#     'Bahrain',
#     'Bahrain islands',
#     'Bahraih',
#     'البحرين',
#     'Languages of Bahrain',
#     'Emirate of Bahrain',
#     'ISO 3166-1:BH',
#     'Bahrain Islands',
#     'Mamlakat al-Baḥrayn',
#     "Bahrain's",
#     'Bahrain/Geography',
#     'Al-Baḥrayn',
#     'Barhain',
#     'Kingdom of Bahrain',
#     '1923 Sitrah Outrage',
#     'Al-Bahrayn'],
#    'MatchedWikiEntityName': 'Bahrain',
#    'NormalizedAliases': ['iso 3166 1 bh',
#     'bahrain',
#     'barhain',
#     'bahrayn',
#     'languages of bahrain',
#     'al baḥrayn',
#     'emirate of bahrain',
#     'mamlakat al baḥrayn',
#     'bahrain geography',
#     'dawlat al bahrain',
#     'etymology of bahrain',
#     'bahrein islands',
#     'bahrain s',
#     'مملكة البحرين',
#     '1923 sitrah outrage',
#     'bahrain islands',
#     'asia bahrain',
#     'bahrein',
#     'kingdom of bahrain',
#     'al bahrayn',
#     'البحرين',
#     'bahraih'],
#    'NormalizedMatchedWikiEntityName': 'bahrain',
#    'NormalizedValue': 'bahrain',
#    'Type': 'WikipediaEntity',
#    'Value': 'Bahrain'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Tylos.txt',
#     'Title': 'Tylos'}],
#   'Question': 'Which country was formerly known by the Greeks as Tylos?',
#   'QuestionId': 'qb_5539',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'countri formerli know greek tylo'},
#  {'Answer': {'Aliases': ['Ruth Davis',
#     'Arthur Farnsworth.',
#     'Harmon Nelson',
#     'Davis, Bette',
#     'Bette Davies',
#     "Arthur Farnsworth (Bette Davis' husband)",
#     'Ruth Elizabeth Davis',
#     'Bette Davis',
#     'Ruth Elizabeth %22Bette%22 Davis',
#     'Bettie Davis'],
#    'MatchedWikiEntityName': 'Bette Davis',
#    'NormalizedAliases': ['ruth davis',
#     'arthur farnsworth',
#     'arthur farnsworth bette davis husband',
#     'bettie davis',
#     'davis bette',
#     'ruth elizabeth 22bette 22 davis',
#     'ruth elizabeth davis',
#     'bette davies',
#     'harmon nelson',
#     'bette davis'],
#    'NormalizedMatchedWikiEntityName': 'bette davis',
#    'NormalizedValue': 'bette davis',
#    'Type': 'WikipediaEntity',
#    'Value': 'Bette Davis'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'All_About_Eve.txt',
#     'Title': 'All About Eve'},
#    {'DocSource': 'TagMe',
#     'Filename': '1950_in_film.txt',
#     'Title': '1950 in film'}],
#   'Question': 'Who played Margo Channing in the 1950 film ‘All About Eve’?',
#   'QuestionId': 'qb_5541',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'play margo chann 1950 film eve'},
#  {'Answer': {'Aliases': ['Tigris',
#     'Dicle River',
#     'The Tigris',
#     'Tigrus',
#     'Aranzahas',
#     'The Tigris River',
#     'Hiddekel',
#     'River Tigris',
#     'Tigris River',
#     'Tigres R.',
#     'Tigris river',
#     'Deqlath'],
#    'MatchedWikiEntityName': 'Tigris',
#    'NormalizedAliases': ['river tigris',
#     'dicle river',
#     'tigrus',
#     'tigres r',
#     'aranzahas',
#     'tigris',
#     'deqlath',
#     'tigris river',
#     'hiddekel'],
#    'NormalizedMatchedWikiEntityName': 'tigris',
#    'NormalizedValue': 'river tigris',
#    'Type': 'WikipediaEntity',
#    'Value': 'River Tigris'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Baghdad.txt',
#     'Title': 'Baghdad'}],
#   'Question': 'The city of Baghdad lies on which river?',
#   'QuestionId': 'qb_5544',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'citi baghdad lie river'},
#  {'Answer': {'Aliases': ['Left (disambiguation)', 'Left (album)', 'Left'],
#    'MatchedWikiEntityName': 'Left',
#    'NormalizedAliases': ['left album', 'left disambiguation', 'left'],
#    'NormalizedMatchedWikiEntityName': 'left',
#    'NormalizedValue': 'left',
#    'Type': 'WikipediaEntity',
#    'Value': 'Left'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Australia.txt',
#     'Title': 'Australia'}],
#   'Question': 'On which side of the road do motorists drive in Australia?',
#   'QuestionId': 'qb_5547',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'side road motorist drive australia'},
#  {'Answer': {'Aliases': ['Stephen Fry',
#     'Stephen fry',
#     'Steven fry',
#     'Steve Fry',
#     '@stephenfry',
#     'Steven Fry',
#     'Rescuing the Spectacled Bear'],
#    'MatchedWikiEntityName': 'Stephen Fry',
#    'NormalizedAliases': ['stephen fry',
#     'stephenfry',
#     'rescuing spectacled bear',
#     'steven fry',
#     'steve fry'],
#    'NormalizedMatchedWikiEntityName': 'stephen fry',
#    'NormalizedValue': 'stephen fry',
#    'Type': 'WikipediaEntity',
#    'Value': 'Stephen Fry'},
#   'EntityPages': [{'DocSource': 'TagMe', 'Filename': 'QI.txt', 'Title': 'QI'}],
#   'Question': 'Who is the host of the BBC television show QI?',
#   'QuestionId': 'qb_5564',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'host bbc televis show qi'},
#  {'Answer': {'Aliases': ['Diamond',
#     "4-C's of Diamond Grading",
#     "The 4 C's Of Diamonds",
#     'Polished diamond',
#     'Diamonds',
#     'Natural diamond',
#     'Diamond industry',
#     'Mitre-crozier applique',
#     'Diamond powder',
#     'Bortz',
#     'Industrial diamonds',
#     'Type-II diamond',
#     'Daimonds',
#     'Mitre-crozier appliqué',
#     'Impact diamonds',
#     'Diamonad',
#     'Industrial diamond',
#     'Industrial Diamond'],
#    'MatchedWikiEntityName': 'Diamond',
#    'NormalizedAliases': ['4 c s of diamonds',
#     'polished diamond',
#     '4 c s of diamond grading',
#     'industrial diamonds',
#     'type ii diamond',
#     'mitre crozier applique',
#     'diamond powder',
#     'diamonds',
#     'industrial diamond',
#     'diamond',
#     'diamond industry',
#     'daimonds',
#     'bortz',
#     'natural diamond',
#     'mitre crozier appliqué',
#     'impact diamonds',
#     'diamonad'],
#    'NormalizedMatchedWikiEntityName': 'diamond',
#    'NormalizedValue': 'diamonds',
#    'Type': 'WikipediaEntity',
#    'Value': 'Diamonds'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Diamond_cut.txt',
#     'Title': 'Diamond cut'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Diamond_clarity.txt',
#     'Title': 'Diamond clarity'},
#    {'DocSource': 'TagMe',
#     'Filename': 'Carat_(mass).txt',
#     'Title': 'Carat (mass)'}],
#   'Question': 'Cut, colour, clarity and carat are all considered when purchasing what?',
#   'QuestionId': 'qb_5565',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'cut colour clariti carat consid purchas'},
#  {'Answer': {'Aliases': ['Margrete',
#     'Margaret (name)',
#     'Margarete',
#     'Margaret film',
#     'Margaret (film)',
#     'Margaret movie',
#     'Margaret Christina',
#     'Margaret',
#     'Marketta',
#     'Μαργαρίτα'],
#    'MatchedWikiEntityName': 'Margaret',
#    'NormalizedAliases': ['margrete',
#     'margarete',
#     'margaret',
#     'margaret christina',
#     'μαργαρίτα',
#     'margaret movie',
#     'margaret film',
#     'margaret name',
#     'marketta'],
#    'NormalizedMatchedWikiEntityName': 'margaret',
#    'NormalizedValue': 'margaret',
#    'Type': 'WikipediaEntity',
#    'Value': 'Margaret'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Prime_Minister_of_the_United_Kingdom.txt',
#     'Title': 'Prime Minister of the United Kingdom'}],
#   'Question': 'What was the name of the first wife of former British Prime Minister Margaret Thatcher’s husband Denis?',
#   'QuestionId': 'qb_5582',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'name first wife former british prime minist margaret thatcher husband deni'},
#  {'Answer': {'Aliases': ['N. Lenin',
#     'Vladimir Lennon',
#     'Vladimir lenin',
#     'Vladimir Lenin',
#     'VI Lenin',
#     'V I Lenin',
#     'Vladimir lennon',
#     "Vladimir Il'ich Lenin",
#     'Lenin, V. I.',
#     'Vladimir Ilych Ulyanov',
#     'Comrade Lenin',
#     'Nikolay Lenin',
#     'Vladimir Ilyich Ulianov',
#     'Vladimir Ilyich Ulyanov Lenin',
#     'Lennin',
#     'Lenin, V.I.',
#     'Владимир Ленин',
#     'V.I. Ulyanov',
#     'Vladimir Ilyich',
#     'Vladimir Ulyanov',
#     'Владимир Ильич Ленин',
#     'V. Lenin',
#     'Nicolai Lenin',
#     'Vladimir I. Lenin',
#     'V.I. Lenin',
#     'Влади́мир Ильи́ч Ле́нин',
#     'Vladimir Ilyich Lenin',
#     'Ленина',
#     'V. I. Lenin',
#     'Ленин',
#     'Влади́мир Ильи́ч Улья́нов',
#     'Vladmir Lenin',
#     'Vladimir Ilich Lenin',
#     'Lenin',
#     'Vladimir Ilich Ulyanov',
#     'Vladimir Illich Lenin',
#     'Vladimir Ilyich Ulyanov',
#     'V. I. Ulyanov',
#     'Nikolai Lenin',
#     'Ле́нин'],
#    'MatchedWikiEntityName': 'Vladimir Lenin',
#    'NormalizedAliases': ['влади́мир ильи́ч улья́нов',
#     'comrade lenin',
#     'vladimir ilyich',
#     'vladimir illich lenin',
#     'v i lenin',
#     'влади́мир ильи́ч ле́нин',
#     'vi lenin',
#     'vladimir ilich lenin',
#     'lenin v i',
#     'vladimir ilyich ulyanov lenin',
#     'vladimir lenin',
#     'nicolai lenin',
#     'ленина',
#     'vladimir il ich lenin',
#     'vladimir ulyanov',
#     'vladimir ilyich ulianov',
#     'vladmir lenin',
#     'lenin',
#     'nikolay lenin',
#     'vladimir ilich ulyanov',
#     'владимир ильич ленин',
#     'v lenin',
#     'n lenin',
#     'ле́нин',
#     'nikolai lenin',
#     'lennin',
#     'владимир ленин',
#     'v i ulyanov',
#     'vladimir lennon',
#     'vladimir ilyich ulyanov',
#     'vladimir ilyich lenin',
#     'vladimir ilych ulyanov',
#     'ленин',
#     'vladimir i lenin'],
#    'NormalizedMatchedWikiEntityName': 'vladimir lenin',
#    'NormalizedValue': 'lenin',
#    'Type': 'WikipediaEntity',
#    'Value': 'Lenin'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'The_Good_Life_(1975_TV_series).txt',
#     'Title': 'The Good Life (1975 TV series)'}],
#   'Question': 'What is the name of the cockerel in the UK television series ‘The Good Life’?',
#   'QuestionId': 'qb_5590',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'name cockerel uk televis seri good life'},
#  {'Answer': {'Aliases': ['Wasps RFC',
#     'Wasps (rugby)',
#     'Wasps R.F.C.',
#     'London Wasps',
#     'London wasps'],
#    'MatchedWikiEntityName': 'Wasps RFC',
#    'NormalizedAliases': ['wasps rfc',
#     'wasps rugby',
#     'wasps r f c',
#     'london wasps'],
#    'NormalizedMatchedWikiEntityName': 'wasps rfc',
#    'NormalizedValue': 'london wasps',
#    'Type': 'WikipediaEntity',
#    'Value': 'London Wasps'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Adams_Park.txt',
#     'Title': 'Adams Park'}],
#   'Question': 'Which English Rugby Union team play their home games at Adams Park?',
#   'QuestionId': 'qb_5601',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'english rugbi union team play home game adam park'},
#  {'Answer': {'Aliases': ['Englnad',
#     'The land of the Angles',
#     'Sasainn',
#     'England, U.K.',
#     'Engla land',
#     "England's",
#     'Starks Field School',
#     'Englaland',
#     'English Nation',
#     'Ingland',
#     'Engelond',
#     'Englistan',
#     'Languages of England',
#     'England, UK',
#     'Name of England',
#     'Auld enemy',
#     'Sasana',
#     'England, United Kingdom',
#     'Ængland',
#     'Lloegr',
#     'Land of the Angles',
#     'Engla rice',
#     'Aengland',
#     'UK, (England)',
#     'Ænglaland',
#     'England',
#     'Life in England',
#     'Aenglaland',
#     'ENGLAND',
#     'Anglica',
#     'Etymology of England',
#     'Pow Sows',
#     'Ængla land'],
#    'MatchedWikiEntityName': 'England',
#    'NormalizedAliases': ['englaland',
#     'england uk',
#     'england s',
#     'engla rice',
#     'englistan',
#     'lloegr',
#     'england united kingdom',
#     'sasana',
#     'ingland',
#     'england',
#     'pow sows',
#     'engelond',
#     'starks field school',
#     'aengland',
#     'sasainn',
#     'languages of england',
#     'engla land',
#     'etymology of england',
#     'englnad',
#     'english nation',
#     'auld enemy',
#     'ænglaland',
#     'land of angles',
#     'england u k',
#     'aenglaland',
#     'name of england',
#     'ængland',
#     'anglica',
#     'uk england',
#     'life in england',
#     'ængla land'],
#    'NormalizedMatchedWikiEntityName': 'england',
#    'NormalizedValue': 'england',
#    'Type': 'WikipediaEntity',
#    'Value': 'England'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': 'Cricket.txt',
#     'Title': 'Cricket'},
#    {'DocSource': 'TagMe',
#     'Filename': '2009_Ashes_series.txt',
#     'Title': '2009 Ashes series'},
#    {'DocSource': 'Search',
#     'Filename': 'The_Ashes.txt',
#     'Title': 'The Ashes',
#     'originalUrl': 'http://schools-wikipedia.org/wp/t/The_Ashes.htm'},
#    {'DocSource': 'Search',
#     'Filename': 'England_cricket_team.txt',
#     'Title': 'England cricket team',
#     'originalUrl': 'http://schools-wikipedia.org/wp/e/England_cricket_team.htm'}],
#   'Question': 'In cricket, which nation won the 2009 Ashes series?',
#   'QuestionId': 'qb_5615',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'cricket nation 2009 ash seri'},
#  {'Answer': {'Aliases': ['Butchers',
#     'The butcher',
#     'Boning',
#     'Butchers shop',
#     'Butchering',
#     'Butchers shops',
#     'Secondary butchery',
#     'The Butcher',
#     'Butcher shops',
#     'Butcher',
#     "Butcher's shops",
#     'Secondary butchering',
#     'Butcher shop',
#     "Butchers' shop",
#     "Butchers' shops",
#     'Butchered',
#     'Boucherie',
#     'Butchery',
#     "Butcher's shop"],
#    'MatchedWikiEntityName': 'Butcher',
#    'NormalizedAliases': ['secondary butchery',
#     'boucherie',
#     'butchery',
#     'butcher shop',
#     'boning',
#     'butchers shops',
#     'butchered',
#     'butcher s shop',
#     'butcher',
#     'butcher shops',
#     'butcher s shops',
#     'butchers shop',
#     'butchering',
#     'butchers',
#     'secondary butchering'],
#    'NormalizedMatchedWikiEntityName': 'butcher',
#    'NormalizedValue': 'butcher',
#    'Type': 'WikipediaEntity',
#    'Value': 'Butcher'},
#   'EntityPages': [{'DocSource': 'TagMe',
#     'Filename': "Dad's_Army.txt",
#     'Title': "Dad's Army"}],
#   'Question': 'In the UK television series ‘Dad’s Army’, what was Lance-Corpopal Jack Jones occupation?',
#   'QuestionId': 'qb_5618',
#   'QuestionSource': 'http://www.quizballs.com/',
#   'Question_preprocessed': 'uk televis seri dad armi lanc corpop jack jone occup'},
#  ...]

# %% [markdown]
# ### Helper functions

# %%
def term_counter_for_text(text):
  
  words = text.split(" ")
  terms_counter = Counter(words) # count words in the text
  del terms_counter['']
  
  return terms_counter

# %% [markdown]
# function that prints the memory space for a dictionary:

# %%
import sys

def print_size_of_dict(name, dictionary):
  sum = sys.getsizeof(dictionary)

  for key, value in dictionary.items():
    sum +=  sys.getsizeof(value)

  print('Size of dict',name, ':', int(sum/1024/1024), 'MB')

# %% [markdown]
# ### Inverted Index

# %%
inverted_index_wiki_dict = {} # will hold the postings lists for each term

term_counters_by_document = {} # will hold the raw term counts for each document
document_lengths = {} 

progress = 0
for document, text in list(documents_dict_wiki.items()):
  
  term_counter = term_counter_for_text(text)

  if len(term_counter) == 0: # there are some empty docs in the corpus
    print(document)
    continue

  term_counters_by_document[document] = term_counter # add the term counts for the doc to the dictionary of docs
  document_lengths[document] = sum(term_counter.values())

  for term in term_counter.keys():
    inverted_index_wiki_dict.setdefault(term, []).append(document)

print("Number of words in corpus: ", len(inverted_index_wiki_dict.keys()))
# Out:
# AFAIK.txt
# Against_All_Odds_(Take_a_Look_at_Me_Now).txt
# Ailurophile.txt
# Alexander_I_of_Yugoslavia.txt
# Bathophobia.txt
# Bernicia.txt
# Category_Australian_poets.txt
# Category_Battles_of_the_Franco-Prussian_War.txt
# Category_BBC_Radio_5_Live_presenters.txt
# Category_Chess_notation.txt
# Category_Children's_television_channels_in_India.txt
# Category_Detective_television_series.txt
# Category_Directors_of_the_National_Gallery,_London.txt
# Category_Landlocked_countries.txt
# Category_Lists_of_lakes_by_country.txt
# Category_Lists_of_rivers_by_country.txt
# Category_Mexican_bullfighters.txt
# Category_New_Zealand_opera_singers.txt
# Category_Olympic_gold_medalists_for_Finland.txt
# Category_Severn_drainage_basin.txt
# Category_Stop-motion_animated_television_series.txt
# Category_1945_films.txt
# Category_1950s_3D_films.txt
# Category_19th-century_French_people.txt
# Category_Airports_in_the_United_States.txt
# Category_Terrestrial_planets.txt
# Category_Tributaries_of_the_River_Severn.txt
# Category_Units_of_measurement.txt
# Daisy_Roots.txt
# Deira.txt
# Ferdinand_Marcos.txt
# File_The_Nightwatch_by_Rembrandt.jpg.txt
# FTFY.txt
# Galeophobia.txt
# German_South-West_Africa.txt
# Good_Morning,_Vietnam.txt
# Grantham_Hospital.txt
# In_the_Midnight_Hour.txt
# John_Dillinger.txt
# Kurdufan.txt
# List_of_cities_and_boroughs_in_Pennsylvania_by_population.txt
# List_of_Latin_phrases_(I).txt
# Lusitania.txt
# Portal_Harry_Potter.txt
# Portal_Law.txt
# Portal_Motorsport.txt
# Portal_Atlas.txt
# Portal_Australia.txt
# Romney_Marsh.txt
# Ross_Poldark.txt
# Saxe-Coburg.txt
# Schneider_Trophy_aircraft.txt
# State_of_Franklin.txt
# Template_Capital_cities_of_European_Union_member_states.txt
# Template_Football_manager_history.txt
# Template_Infobox_country.txt
# Template_Infobox_television.txt
# Template_Lagomorpha.txt
# Template_Largest_cities_of_South_Africa.txt
# Template_Male_golfers_who_have_won_2_or_more_Major_Championships_in_one_year.txt
# Template_Monopoly_board_layout.txt
# Template_Reagan_cabinet.txt
# Template_Shakespeare's_plays.txt
# Template_Timeline_of_the_Lewis_and_Clark_Expedition.txt
# Titania.txt
# UK_railway_stations_–_B.txt
# Verdun.txt
# Wikipedia_WikiProject_Dogs.txt
# Wikipedia_Release_Version.txt
# Wikipedia_Featured_articles.txt
# Yankee_Doodle.txt
# Number of words in corpus:  1079375

# %%
print_size_of_dict('inverted index', inverted_index_wiki_dict)
print_size_of_dict('term_counters_by_document', term_counters_by_document)
# Out:
# Size of dict inverted index : 511 MB
# Size of dict term_counters_by_document : 1738 MB

# %% [markdown]
# ###Compute idf weights for all terms:
#
# idf taken from https://en.wikipedia.org/wiki/Okapi_BM25#The_ranking_function

# %%
idfs = {}
number_of_documents = len(term_counters_by_document)
for term, posting_list in inverted_index_wiki_dict.items():
  number_of_docs_with_term = len(posting_list)
  idfs[term] = np.log(1 + (number_of_documents - number_of_docs_with_term + 0.5) / (number_of_docs_with_term + 0.5))

#print_size_of_dict('idfs', idfs)
#list(idfs.items())[:10]

# %% [markdown]
# ### BM25 Scoring function

# %%
average_document_length = sum(document_lengths.values()) / number_of_documents

def score(term, document, k1, b):
  raw_count = term_counters_by_document[document][term]
  return idfs[term] * ((raw_count * (k1 + 1)) / (raw_count + (k1 * (1 - b + b * document_lengths[document] / average_document_length))))

# %%
def BM25rank(query, top_k, k1 = 1.5, b = 0.75):
  scores = {}
  query_terms = term_counter_for_text(query).keys()

  for term in query_terms:
    posting_list = inverted_index_wiki_dict.get(term, []) # only look at documents that actually contain the term
    for document in posting_list:
      scores[document] = scores.get(document, 0) + score(term, document, k1, b)

  sorted_scores = sorted(scores.items(), reverse=True, key=lambda item: item[1])
  return sorted_scores[:top_k]

# %%
BM25rank("lloyd webber music premier 10th decemb 1993", 10)
# Out:
# [('Julian_Lloyd_Webber.txt', 29.39136583238563),
#  ('Adelphi_Theatre.txt', 29.352536085427317),
#  ('Andrew_Lloyd_Webber.txt', 29.001668204913347),
#  ('Sunset_Boulevard_(musical).txt', 28.975076592109684),
#  ('The_Phantom_of_the_Opera_(1986_musical).txt', 28.945679198257686),
#  ("I_Don't_Know_How_to_Love_Him.txt", 28.188574982451904),
#  ('Michael_Ball_(singer).txt', 28.114409499610833),
#  ('Michael_Crawford.txt', 27.429953679132367),
#  ('Sarah_Brightman.txt', 27.384611555644376),
#  ('Marti_Webb.txt', 26.723444003361852)]

# %% [markdown]
# ## Save documents retrieved for query w/ score to access for evaluation

# %%
import multiprocessing as mp
import datetime

def runBM25(idxKeyQuestion):
    (idx, (key, question)) = idxKeyQuestion

    if idx % 500 == 0:
        print(idx, datetime.datetime.now())

    return key, BM25rank(question, 500)

def query_retrieved_docs(qas):
    print("querying docs:", len(qas))
    
    with mp.Pool(mp.cpu_count()) as pool:
        simple_qas = list(map(lambda qa: (qa['QuestionId'], qa["Question_preprocessed"]), qas))
        key_answers = pool.imap_unordered(runBM25, enumerate(simple_qas), chunksize=2)
        result = dict(key_answers)
        
    return result

# %%
## Retrieve Documents for dev set
wiki_dev_query_results = query_retrieved_docs(qa_wiki_dev_dict)
save_as_pickle(wiki_dev_query_results, bm25_retrieval_wiki_dev_docs_scores)
print_size_of_dict('wiki_dev_query_results', wiki_dev_query_results)
# Out:
# querying docs: 7993
# 0 2021-05-02 17:46:26.302403
# 500 2021-05-02 17:46:54.561611
# 1000 2021-05-02 17:47:20.058926
# 1500 2021-05-02 17:47:45.744798
# 2000 2021-05-02 17:48:14.009692
# 2500 2021-05-02 17:48:49.026961
# 3000 2021-05-02 17:49:20.642811
# 3500 2021-05-02 17:49:58.235993
# 4000 2021-05-02 17:50:27.700489
# 4500 2021-05-02 17:50:54.731572
# 5000 2021-05-02 17:51:21.909946
# 5500 2021-05-02 17:51:50.045499
# 6000 2021-05-02 17:52:19.026224
# 6500 2021-05-02 17:52:53.354395
# 7000 2021-05-02 17:53:22.672165
# 7500 2021-05-02 17:53:47.204547
# Size of dict wiki_dev_query_results : 35 MB

# %%
## Retrieve Documents for verified dev set - Subset of DEV SET!!
wiki_dev_ver_query_results = query_retrieved_docs(qa_wiki_dev_verified_dict)
save_as_pickle(wiki_dev_ver_query_results, bm25_retrieval_wiki_dev_verified_docs_scores)
print_size_of_dict('wiki_dev_ver_query_results', wiki_dev_ver_query_results)
# Out:
# querying docs: 318
# 0 2021-05-02 17:45:29.426422
# Size of dict wiki_dev_ver_query_results : 1 MB

# %%
## Retrieve Documents for train set
wiki_train_query_results = query_retrieved_docs(qa_wiki_train_dict)
save_as_pickle(wiki_train_query_results, bm25_retrieval_wiki_train_docs_scores)
print_size_of_dict('wiki_train_query_results', wiki_train_query_results)
# Out:
# querying docs: 61888
# 0 2021-05-02 17:54:50.615154
# 500 2021-05-02 17:55:15.026945
# 1000 2021-05-02 17:55:38.485572
# 1500 2021-05-02 17:56:01.901730
# 2000 2021-05-02 17:56:23.669999
# 2500 2021-05-02 17:56:38.497276
# 3000 2021-05-02 17:56:51.650109
# 3500 2021-05-02 17:57:05.152251
# 4000 2021-05-02 17:57:18.026136
# 4500 2021-05-02 17:57:30.435087
# 5000 2021-05-02 17:57:42.456308
# 5500 2021-05-02 17:57:54.665583
# 6000 2021-05-02 17:58:06.956980
# 6500 2021-05-02 17:58:19.243857
# 7000 2021-05-02 17:58:31.929078
# 7500 2021-05-02 17:58:43.969402
# 8000 2021-05-02 17:58:56.316406
# 8500 2021-05-02 17:59:09.766235
# 9000 2021-05-02 17:59:23.011739
# 9500 2021-05-02 17:59:36.983235
# 10000 2021-05-02 17:59:49.605091
# 10500 2021-05-02 18:00:00.787952
# 11000 2021-05-02 18:00:12.234456
# 11500 2021-05-02 18:00:22.827254
# 12000 2021-05-02 18:00:34.427009
# 12500 2021-05-02 18:00:46.188072
# 13000 2021-05-02 18:00:57.683369
# 13500 2021-05-02 18:01:10.922699
# 14000 2021-05-02 18:01:28.169462
# 14500 2021-05-02 18:01:46.112994
# 15000 2021-05-02 18:02:04.009338
# 15500 2021-05-02 18:02:19.838505
# 16000 2021-05-02 18:02:34.850041
# 16500 2021-05-02 18:02:50.155372
# 17000 2021-05-02 18:03:06.130177
# 17500 2021-05-02 18:03:21.108921
# 18000 2021-05-02 18:03:35.272514
# 18500 2021-05-02 18:03:50.184942
# 19000 2021-05-02 18:04:03.837565
# 19500 2021-05-02 18:04:17.174674
# 20000 2021-05-02 18:04:29.552672
# 20500 2021-05-02 18:04:43.479289
# 21000 2021-05-02 18:05:00.074069
# 21500 2021-05-02 18:05:16.809628
# 22000 2021-05-02 18:05:33.081326
# 22500 2021-05-02 18:05:50.112789
# 23000 2021-05-02 18:06:06.625804
# 23500 2021-05-02 18:06:25.159981
# 24000 2021-05-02 18:06:42.703618
# 24500 2021-05-02 18:06:58.259990
# 25000 2021-05-02 18:07:14.413209
# 25500 2021-05-02 18:07:30.413975
# 26000 2021-05-02 18:07:46.554451
# 26500 2021-05-02 18:08:03.282533
# 27000 2021-05-02 18:08:19.679022
# 27500 2021-05-02 18:08:35.715616
# 28000 2021-05-02 18:08:52.992838
# 28500 2021-05-02 18:09:05.441050
# 29000 2021-05-02 18:09:16.270732
# 29500 2021-05-02 18:09:25.973349
# 30000 2021-05-02 18:09:35.644814
# 30500 2021-05-02 18:09:45.711504
# 31000 2021-05-02 18:09:57.741953
# 31500 2021-05-02 18:10:10.479577
# 32000 2021-05-02 18:10:24.191779
# 32500 2021-05-02 18:10:35.810443
# 33000 2021-05-02 18:10:49.391274
# 33500 2021-05-02 18:11:01.621549
# 34000 2021-05-02 18:11:13.271945
# 34500 2021-05-02 18:11:25.052843
# 35000 2021-05-02 18:11:37.515186
# 35500 2021-05-02 18:11:50.938855
# 36000 2021-05-02 18:12:03.386808
# 36500 2021-05-02 18:12:16.142309
# 37000 2021-05-02 18:12:28.412632
# 37500 2021-05-02 18:12:40.462088
# 38000 2021-05-02 18:12:53.086982
# 38500 2021-05-02 18:13:05.696167
# 39000 2021-05-02 18:13:18.647750
# 39500 2021-05-02 18:13:30.967633
# 40000 2021-05-02 18:13:44.045952
# 40500 2021-05-02 18:13:56.924248
# 41000 2021-05-02 18:14:09.785481
# 41500 2021-05-02 18:14:22.909658
# 42000 2021-05-02 18:14:35.684097
# 42500 2021-05-02 18:14:48.697684
# 43000 2021-05-02 18:15:01.622990
# 43500 2021-05-02 18:15:14.730544
# 44000 2021-05-02 18:15:27.845543
# 44500 2021-05-02 18:15:41.453454
# 45000 2021-05-02 18:15:54.921047
# 45500 2021-05-02 18:16:07.725576
# 46000 2021-05-02 18:16:21.003723
# 46500 2021-05-02 18:16:40.249362
# 47000 2021-05-02 18:17:03.846724
# 47500 2021-05-02 18:17:20.326740
# 48000 2021-05-02 18:17:33.363953
# 48500 2021-05-02 18:17:48.402775
# 49000 2021-05-02 18:18:01.916828
# 49500 2021-05-02 18:18:15.626288
# 50000 2021-05-02 18:18:29.477575
# 50500 2021-05-02 18:18:43.469630
# 51000 2021-05-02 18:18:56.479108
# 51500 2021-05-02 18:19:10.403423
# 52000 2021-05-02 18:19:24.205756
# 52500 2021-05-02 18:19:37.530330
# 53000 2021-05-02 18:19:51.254125
# 53500 2021-05-02 18:20:05.062952
# 54000 2021-05-02 18:20:19.379558
# 54500 2021-05-02 18:20:33.687277
# 55000 2021-05-02 18:20:47.808785
# 55500 2021-05-02 18:21:00.339088
# 56000 2021-05-02 18:21:10.880499
# 56500 2021-05-02 18:21:22.319497
# 57000 2021-05-02 18:21:33.669219
# 57500 2021-05-02 18:21:44.437410
# 58000 2021-05-02 18:21:55.890220
# 58500 2021-05-02 18:22:07.353822
# 59000 2021-05-02 18:22:18.365102
# 59500 2021-05-02 18:22:31.705016
# 60000 2021-05-02 18:22:52.007210
# 60500 2021-05-02 18:23:12.140486
# 61000 2021-05-02 18:23:31.191504
# 61500 2021-05-02 18:23:49.029333
# Size of dict wiki_train_query_results : 273 MB

# %%
## Retrieve Documents for test set
wiki_test_query_results = query_retrieved_docs(qa_wiki_test_dict)
save_as_pickle(wiki_test_query_results, bm25_retrieval_wiki_test_docs_scores)
print_size_of_dict('wiki_test_query_results', wiki_test_query_results)
# Out:
# querying docs: 7701
# 0 2021-05-02 18:25:28.834834
# 500 2021-05-02 18:25:41.102183
# 1000 2021-05-02 18:25:53.547694
# 1500 2021-05-02 18:26:05.584208
# 2000 2021-05-02 18:26:19.597481
# 2500 2021-05-02 18:26:34.462380
# 3000 2021-05-02 18:26:50.997676
# 3500 2021-05-02 18:27:07.555352
# 4000 2021-05-02 18:27:19.178095
# 4500 2021-05-02 18:27:31.533639
# 5000 2021-05-02 18:27:44.250248
# 5500 2021-05-02 18:27:57.586517
# 6000 2021-05-02 18:28:13.736967
# 6500 2021-05-02 18:28:28.335430
# 7000 2021-05-02 18:28:41.625128
# 7500 2021-05-02 18:28:53.770278
# Size of dict wiki_test_query_results : 34 MB
