# %% [markdown]
# # Answer Extraction Pipeline for TriviaQA
#
# Contains dataset preprocessing, training and evaluation code for the question answering task using RoBERTa.

# %%
# !nvidia-smi
# Out:
# Tue Jun  8 16:32:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 466.27       Driver Version: 466.27       CUDA Version: 11.3     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# | 21%   62C    P2    64W / 250W |  11070MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1516    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      1588    C+G   ...zilla Firefox\firefox.exe    N/A      |
# |    0   N/A  N/A      4464    C+G   ...udibleRT.WindowsPhone.exe    N/A      |
# |    0   N/A  N/A      6676    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A      6988    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A      8220      C   ...t\venv\Scripts\python.exe    N/A      |
# |    0   N/A  N/A      9532    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A     10304    C+G   ...nputApp\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     10320    C+G   ...ekyb3d8bbwe\YourPhone.exe    N/A      |
# |    0   N/A  N/A     10376    C+G   ...kyb3d8bbwe\Calculator.exe    N/A      |
# |    0   N/A  N/A     10780    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     10852    C+G   ...4__htrsf667h5kn2\AWCC.exe    N/A      |
# |    0   N/A  N/A     10928    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A     13420    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     13648    C+G   ...perience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     14580    C+G   ...signal-desktop\Signal.exe    N/A      |
# |    0   N/A  N/A     14696    C+G   ...perience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     14924    C+G   ...zilla Firefox\firefox.exe    N/A      |
# |    0   N/A  N/A     15504    C+G   ...s\Nextcloud\nextcloud.exe    N/A      |
# |    0   N/A  N/A     15876    C+G   ...8wekyb3d8bbwe\Cortana.exe    N/A      |
# |    0   N/A  N/A     16532    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     17628    C+G   ...in7x64\steamwebhelper.exe    N/A      |
# |    0   N/A  N/A     21204    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Installs and Imports

# %%
# !pip install transformers
# !pip install datasets
# Out:
# Requirement already satisfied: transformers in d:\mimis-stuff\ir-project\venv\lib\site-packages (4.6.1)
# Requirement already satisfied: requests in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (2.25.1)
# Requirement already satisfied: importlib-metadata in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (4.3.1)
# Requirement already satisfied: huggingface-hub==0.0.8 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (0.0.8)
# Requirement already satisfied: tqdm>=4.27 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (4.49.0)
# Requirement already satisfied: filelock in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (3.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (0.10.3)
# Requirement already satisfied: numpy>=1.17 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (1.19.5)
# Requirement already satisfied: packaging in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (20.9)
# Requirement already satisfied: dataclasses in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (0.8)
# Requirement already satisfied: sacremoses in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (0.0.45)
# Requirement already satisfied: regex!=2019.12.17 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from transformers) (2021.4.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from importlib-metadata->transformers) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from importlib-metadata->transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from requests->transformers) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: click in d:\mimis-stuff\ir-project\venv\lib\site-packages (from sacremoses->transformers) (8.0.1)
# Requirement already satisfied: six in d:\mimis-stuff\ir-project\venv\lib\site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: joblib in d:\mimis-stuff\ir-project\venv\lib\site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: colorama in d:\mimis-stuff\ir-project\venv\lib\site-packages (from click->sacremoses->transformers) (0.4.4)
# Requirement already satisfied: datasets in d:\mimis-stuff\ir-project\venv\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.17 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (1.19.5)
# Requirement already satisfied: pandas in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (1.1.5)
# Requirement already satisfied: xxhash in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: tqdm<4.50.0,>=4.27 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (4.49.0)
# Requirement already satisfied: importlib-metadata in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (4.3.1)
# Requirement already satisfied: requests>=2.19.0 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (2.25.1)
# Requirement already satisfied: pyarrow<4.0.0,>=1.0.0 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (3.0.0)
# Requirement already satisfied: dill in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (0.3.3)
# Requirement already satisfied: huggingface-hub<0.1.0 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (0.0.8)
# Requirement already satisfied: dataclasses in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (0.8)
# Requirement already satisfied: fsspec in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (2021.5.0)
# Requirement already satisfied: multiprocess in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (0.70.11.1)
# Requirement already satisfied: packaging in d:\mimis-stuff\ir-project\venv\lib\site-packages (from datasets) (20.9)
# Requirement already satisfied: filelock in d:\mimis-stuff\ir-project\venv\lib\site-packages (from huggingface-hub<0.1.0->datasets) (3.0.12)
# Requirement already satisfied: idna<3,>=2.5 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from requests>=2.19.0->datasets) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from requests>=2.19.0->datasets) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from requests>=2.19.0->datasets) (1.26.5)
# Requirement already satisfied: typing-extensions>=3.6.4 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from importlib-metadata->datasets) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from importlib-metadata->datasets) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: six>=1.5 in d:\mimis-stuff\ir-project\venv\lib\site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)

# %%
# !pip install pickle5
import pickle5 as pickle
# Out:
# Requirement already satisfied: pickle5 in d:\mimis-stuff\ir-project\venv\lib\site-packages (0.0.11)

# %%
import numpy as np
import os
import re
import random

# %% [markdown]
# ## Run in Google Drive

# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)  

ir_project_drive_folder = "IR Projekt"
data_folder = "/content/drive/My Drive/{}/data/wikipedia".format(ir_project_drive_folder)
models_folder = '/content/drive/My Drive/{}/saved_models'.format(ir_project_drive_folder)

# %% [markdown]
# ## Run Locally

# %%
base_folder = '..'
data_folder = base_folder + '/data'
models_folder = base_folder + '/models'

# %% [markdown]
# ## Files and Folders

# %%
raw_folder = data_folder + '/raw'
preprocessed_folder = data_folder + '/no-pron/preprocessed'

question_answering_models_folder = models_folder + '/question_answering_task'

# qa filenames
qa_wikipedia_verified_dev_filename = raw_folder + '/qa/verified-wikipedia-dev.json'
qa_wikipedia_dev_filename = raw_folder + '/qa/wikipedia-dev.json'
qa_wikipedia_test_without_answers_filename = raw_folder + '/qa/wikipedia-test-without-answers.json'
qa_wikipedia_train_filename = raw_folder + '/qa/wikipedia-train.json'

# evidence files
wikipedia_evidence_file = raw_folder + '/wikipedia_evidence_dict.pkl'

# %%
def save_as_pickle(obj, filename):
    """
    save an object in a pickle file dump
    :param obj: object to dump
    :param filename: target file
    :return:
    """
    directory = os.path.dirname(filename)
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    with open(filename, 'wb') as file:
        pickle.dump(obj, file, protocol=pickle.HIGHEST_PROTOCOL)


def load_pickle(filename):
    """
    load an object from a given pickle file
    :param filename: source file
    :return: loaded object
    """
    with open(filename, 'rb') as file:
        return pickle.load(file)

# %% [markdown]
# ## Load Data

# %%
# Evidence data

documents_dict = load_pickle(wikipedia_evidence_file)
print(len(documents_dict))
# Out:
# 73930

# %% [markdown]
# # Training & Evaluation

# %%
from transformers import RobertaTokenizerFast
tokenizer = RobertaTokenizerFast.from_pretrained("roberta-base")

# %%
pad_to_max_length = True
pad_on_right = False # tokenizer.padding_side == "right"  # Padding side determines if we do (question|context) or (context|question).
doc_stride = 128
max_seq_length = tokenizer.model_max_length

# Postprocessing Config
version_2_with_negative = True
n_best_size = 20
max_answer_length = 50
null_score_diff_threshold = 0

negative_to_positive = 1

# %% [markdown]
# ## Import framework code adapted from [Huggingface Transformers Question Answering](https://github.com/huggingface/transformers/tree/v4.6.1/examples/pytorch/question-answering)

# %%
# %run -i -n QuestionAnsweringTrainerFramework.py

# %% [markdown]
# ## Utils

# %%
def read_trivia_entries(groups):
  answers = groups['Answer']
  questions = groups['Question']
  question_ids = groups['QuestionId']
  entity_pages_list = groups['EntityPages']

  result_ids = []
  result_contexts = []
  result_questions = []
  result_answers = []

  for answer, question, question_id, entity_pages in zip(answers, questions, question_ids, entity_pages_list):
    answer_texts = [answer['Value']] + answer['Aliases']
    if 'HumanAnswers' in answer and answer['HumanAnswers'] is not None:
      answer_texts += answer['HumanAnswers']  

    for entity_page in entity_pages:
      document_name = entity_page['Filename']
      document_name_clean = re.sub("[\?:\*\"]", "_", document_name)
      
      if not document_name_clean in documents_dict:
        continue

      context = documents_dict[document_name_clean]

      found_answer_texts = []
      found_answer_starts = []
      for answer_text in answer_texts:
        try:
          answer_start = context.index(answer_text)
          found_answer_texts.append(answer_text)
          found_answer_starts.append(answer_start)

        except ValueError as e:
          pass

      if len(found_answer_texts) == 0:
        continue

      id = question_id + '__' + document_name

      result_ids.append(id)
      result_contexts.append(context)
      result_questions.append(question)
      result_answers.append({'text': found_answer_texts, 'answer_start': found_answer_starts})

  return {"id": result_ids, "context": result_contexts, "question": result_questions, "answer": result_answers}

# %%
from datasets import load_dataset

def create_qa_dataset(path):
  dataset = load_dataset('json', data_files=[path], field='Data', keep_in_memory=False)["train"]
  return dataset.map(read_trivia_entries, batched=True, remove_columns=dataset.column_names, batch_size=32)

# %% [markdown]
# ## Run Training

# %% [markdown]
# ### Training Data

# %%
dataset_name = "roberta/1positive-to-" + str(negative_to_positive) + "negative"
model_name = "roberta/full_wikipedia-1to" + str(negative_to_positive)

# %%
train_base_dataset_directory = data_folder + "/qa-datasets/" + dataset_name + "/train/base"
train_encodings_dataset_directory = data_folder + "/qa-datasets/" + dataset_name + "/train/encodings"

val_verified_base_dataset_directory = data_folder + "/qa-datasets/" + dataset_name + "/val_verified/base"
val_verified_encodings_dataset_directory = data_folder + "/qa-datasets/" + dataset_name + "/val_verified/encodings"

model_directory = question_answering_models_folder + '/' + model_name

# %% [markdown]
# #### Create Training Dataset and Store it

# %%
train_base_dataset = create_qa_dataset(qa_wikipedia_train_filename)

train_dataset = train_base_dataset.map(
    prepare_train_features,
    batched = True,
    remove_columns = train_base_dataset.column_names,
    batch_size = 32
)

# %%
train_base_dataset.save_to_disk(train_base_dataset_directory)
train_dataset.save_to_disk(train_encodings_dataset_directory)

# %% [markdown]
# #### Load existing Training Dataset

# %%
from datasets import Dataset

train_base_dataset = Dataset.load_from_disk(train_base_dataset_directory)
train_dataset = Dataset.load_from_disk(train_encodings_dataset_directory)

# %% [markdown]
# ### Evaluation Data

# %% [markdown]
# #### Create Evaluation Dataset and Store it

# %%
val_verified_base_dataset = create_qa_dataset(qa_wikipedia_verified_dev_filename)

print(len(val_verified_base_dataset))

val_verified_dataset = val_verified_base_dataset.map(
    prepare_validation_features,
    batched = True,
    remove_columns = val_verified_base_dataset.column_names,
    batch_size = 32
)

# %%
val_verified_base_dataset.save_to_disk(val_verified_base_dataset_directory)
val_verified_dataset.save_to_disk(val_verified_encodings_dataset_directory)

# %% [markdown]
# #### Load existing Evaluation Dataset

# %%
from datasets import Dataset

val_verified_base_dataset = Dataset.load_from_disk(val_verified_base_dataset_directory)
val_verified_dataset = Dataset.load_from_disk(val_verified_encodings_dataset_directory)

# %% [markdown]
# ### Create Metrics

# %%
from datasets import load_metric
from transformers import EvalPrediction

metric = load_metric("squad_v2" if version_2_with_negative else "squad")

def compute_metrics(p: EvalPrediction):
    metrics = metric.compute(predictions = p.predictions, references = p.label_ids, no_answer_threshold=.8)
    metrics["eval_exact"] = metrics["exact"]
    return metrics

# %%
from transformers import RobertaForQuestionAnswering

model = RobertaForQuestionAnswering.from_pretrained('roberta-base')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForQuestionAnswering: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForQuestionAnswering were not initialized from the model checkpoint at roberta-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir = model_directory,# output directory
    num_train_epochs = 5,              # total number of training epochs
    per_device_train_batch_size = 8,  # batch size per device during training
    per_device_eval_batch_size = 32,   # batch size for evaluation
    warmup_steps = 500,                # number of warmup steps for learning rate scheduler
    weight_decay = 0.01,               # strength of weight decay
    logging_dir = model_directory + '/logs',            # directory for storing logs
    logging_steps = 50,
 #   save_steps = 1000,
    save_total_limit = 3,
    evaluation_strategy = "steps",
    eval_steps = 1000,
    load_best_model_at_end = True,
    metric_for_best_model = "eval_exact"
)

trainer = QuestionAnsweringTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_verified_dataset,
    eval_examples=val_verified_base_dataset,
    tokenizer=tokenizer,
    post_process_function=post_processing_function,
    compute_metrics=compute_metrics
)

# %% [markdown]
# ### Run Training

# %%
continue_existing_training = len(os.listdir(model_directory)) > 0

if continue_existing_training:
  print("Checkpoint directory exists. Continuing existing model...")
  train_result = trainer.train(True)
else:
  print("No existing checkpoint found. Starting fresh...")
  train_result = trainer.train()
# Out:
# Checkpoint directory exists. Continuing existing model...
# HBox(children=(FloatProgress(value=0.0, max=6104.0), HTML(value='')))
#     <div>
#
#       <progress value='119092' max='139740' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [119092/139740 8:06:44 < 2:56:02, 1.95 it/s, Epoch 4.26/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th></th>
#       <th>Exact</th>
#       <th>F1</th>
#       <th>Total</th>
#       <th>Exact Thresh</th>
#       <th>F1 Thresh</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>63000</td>
#       <td>0.640300</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>53.054662</td>
#       <td>57.125027</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>64000</td>
#       <td>0.710200</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>55.305466</td>
#       <td>58.913260</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>65000</td>
#       <td>0.747900</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.180064</td>
#       <td>57.964707</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>66000</td>
#       <td>0.627700</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>53.054662</td>
#       <td>57.608870</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>67000</td>
#       <td>0.715000</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>56.913183</td>
#       <td>60.538105</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>68000</td>
#       <td>0.619400</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.662379</td>
#       <td>58.522049</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>69000</td>
#       <td>0.617000</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>55.627010</td>
#       <td>60.183356</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>70000</td>
#       <td>0.627400</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.340836</td>
#       <td>58.600521</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>71000</td>
#       <td>0.614900</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>53.536977</td>
#       <td>58.643532</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>72000</td>
#       <td>0.673600</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>52.733119</td>
#       <td>57.341142</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>73000</td>
#       <td>0.754800</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>52.893891</td>
#       <td>56.369623</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>74000</td>
#       <td>0.592600</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.983923</td>
#       <td>58.463865</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>75000</td>
#       <td>0.615000</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>53.858521</td>
#       <td>58.300796</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>76000</td>
#       <td>0.690500</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>55.305466</td>
#       <td>59.471075</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>77000</td>
#       <td>0.604800</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>55.627010</td>
#       <td>60.447481</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>78000</td>
#       <td>0.591700</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>53.215434</td>
#       <td>58.356500</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>79000</td>
#       <td>0.542300</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>55.305466</td>
#       <td>59.800001</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>80000</td>
#       <td>0.510700</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>55.466238</td>
#       <td>59.541163</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>81000</td>
#       <td>0.637500</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.180064</td>
#       <td>57.890828</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>82000</td>
#       <td>0.641900</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>55.305466</td>
#       <td>59.892053</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>83000</td>
#       <td>0.611400</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.662379</td>
#       <td>58.886780</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>84000</td>
#       <td>0.379900</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.340836</td>
#       <td>58.516690</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>85000</td>
#       <td>0.432700</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.019293</td>
#       <td>58.162481</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>86000</td>
#       <td>0.415300</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>53.376206</td>
#       <td>57.844511</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>87000</td>
#       <td>0.344800</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.662379</td>
#       <td>58.414868</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>88000</td>
#       <td>0.448200</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>52.250804</td>
#       <td>56.268948</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>89000</td>
#       <td>0.415200</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>52.572347</td>
#       <td>56.356990</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>90000</td>
#       <td>0.388300</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>52.090032</td>
#       <td>56.076022</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>91000</td>
#       <td>0.414300</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>53.697749</td>
#       <td>58.559736</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>92000</td>
#       <td>0.488100</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>54.180064</td>
#       <td>58.272261</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>93000</td>
#       <td>0.478900</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>51.607717</td>
#       <td>55.853238</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>94000</td>
#       <td>0.501100</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>52.893891</td>
#       <td>57.147095</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>95000</td>
#       <td>0.522900</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>53.697749</td>
#       <td>58.145940</td>
#       <td>622</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>96000</td>
#       <td>0.438500</td>
#       <td>No log</td>
#       <td>622</td>
#       <td>53.376206</td>
#       <td>56.805053<
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=622.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-112e31e16e06> in <module>
#       3 if continue_existing_training:
#       4   print("Checkpoint directory exists. Continuing existing model...")
# ----> 5   train_result = trainer.train(True)
#       6 else:
#       7   print("No existing checkpoint found. Starting fresh...")
#
# d:\mimis-stuff\ir-project\venv\lib\site-packages\transformers\trainer.py in train(self, resume_from_checkpoint, trial, **kwargs)
#    1270                         tr_loss += self.training_step(model, inputs)
#    1271                 else:
# -> 1272                     tr_loss += self.training_step(model, inputs)
#    1273                 self.current_flos += float(self.floating_point_ops(inputs))
#    1274
#
# d:\mimis-stuff\ir-project\venv\lib\site-packages\transformers\trainer.py in training_step(self, model, inputs)
#    1750             loss = self.deepspeed.backward(loss)
#    1751         else:
# -> 1752             loss.backward()
#    1753
#    1754         return loss.detach()
#
# d:\mimis-stuff\ir-project\venv\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# d:\mimis-stuff\ir-project\venv\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     148
#     149
#
# KeyboardInterrupt:

# %% [markdown]
# ### Run Evaluation

# %%
from transformers.trainer_utils import get_last_checkpoint

model = RobertaForQuestionAnswering.from_pretrained(get_last_checkpoint(model_directory))

training_args = TrainingArguments(
   output_dir = model_directory,# output directory
   per_device_eval_batch_size = 32
)

trainer = QuestionAnsweringTrainer(
    model=model,
    args=training_args,
    eval_dataset=val_verified_dataset,
    eval_examples=val_verified_base_dataset,
    tokenizer=tokenizer,
    post_process_function=post_processing_function,
    compute_metrics=compute_metrics
)

# %%
metrics = trainer.evaluate()
metrics
